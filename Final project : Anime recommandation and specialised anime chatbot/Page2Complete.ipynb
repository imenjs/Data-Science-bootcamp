# %% [markdown]
# # import and install library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/drive/MyDrive/functions.py /content

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 47.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 65.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.5 MB/s eta 0:00:00
# ...

# %%
# !pip install -qqq streamlit --progress-bar off
# !npm install -qqq localtunnel --progress-bar off
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# + off@0.0.10
# added 23 packages from 23 contributors and audited 23 packages in 3.58s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 1 moderate severity vulnerability
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
# !pip install surprise
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3162992 sha256=3959c80b14a056837f7234fe48a889af5090d421d69707d5783655d3d80fc60a
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# ...

# %% [markdown]
# # Import All Table

# %%
user_df
# Out:
#    user_id user_name  age country genre                   mail      password  \
# 0        1    imenjs   36      tn    fm  abidiimen11@gmail.com  1.234560e+05
# 1        2       emy   20      DE     F    imenabidi@gmail.com           NaN
# 2   325639     Luffy   25      ja     M     onepeace@gmail.com           NaN
# 3   325640      sana   42      in     F    abidiimen@gmail.com           NaN
# 4   325640      mimi   15      fr     f         mimi@gmail.com           NaN
# 5   325640   mohamed   31      tn     m           mo@gmail.com           NaN
# 6   325640      momo   43      tn     f       imen11@gmail.com  1.234000e+03
# 7   325640       mim   45      tn     f          mim@gmail.com  1.122334e+07
# 8   325641      Nami   20      Tn     F         Nami@gmail.com  1.122334e+09
#
#   list
# 0   []
# 1   []
# 2   []
# 3   []
# 4   []
# 5   []
# 6   []
# 7   []
# 8   []

# %%
# load the CSV file
import pandas as pd

# Path to the CSV file in your Google Drive
csv_file_path = '/content/drive/MyDrive/user_data.csv'

# Load CSV into DataFrame
user_df = pd.read_csv(csv_file_path)

# %%
user_df
# Out:
#     user_id user_name  age country genre                   mail      password  \
# 0         1    imenjs   36      tn    fm  abidiimen11@gmail.com  1.234560e+05
# 1         2       emy   20      DE     F    imenabidi@gmail.com           NaN
# 2    325639     Luffy   25      ja     M     onepeace@gmail.com           NaN
# 3    325640      sana   42      in     F    abidiimen@gmail.com           NaN
# 4    325640      mimi   15      fr     f         mimi@gmail.com           NaN
# 5    325640   mohamed   31      tn     m           mo@gmail.com           NaN
# 6    325640      momo   43      tn     f       imen11@gmail.com  1.234000e+03
# 7    325640       mim   45      tn     f          mim@gmail.com  1.122334e+07
# 8    325641      Nami   20      Tn     F         Nami@gmail.com  1.122334e+09
# 9    325642     magic   12      US     M  abidiimen11@gmail.com  1.234500e+04
# 10   325643     magic   40      al     m          ime@gmail.com  1.234500e+04
#
#    list
# 0    []
# 1    []
# ...

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/final_animedataset.csv'

# Specify the number of rows to read
nrows = 200000

anime23 = pd.read_csv(file_path, nrows=nrows)

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/animedataset/anime_clean.csv'

# Specify the number of rows to read
nrows = 15000

anime = pd.read_csv(file_path) #, nrows=nrows)
anime_df = anime.copy()

# %%
anime_df = pd.DataFrame(anime_df)

# %%
anime_df
# Out:
#          uid                                              title  \
# 0      28891                              Haikyuu Second Season
# 1      23273                            Shigatsu wa Kimi no Uso
# 2      34599                                      Made in Abyss
# 3       5114                    Fullmetal Alchemist Brotherhood
# 4      31758                     Kizumonogatari III Reiketsuhen
# ...      ...                                                ...
# 15962  16934  Chuunibyou demo Koi ga Shitai Kirameki no Slap...
# 15963      2                                       Demon Slayer
# 15964      3                                     Jujutsu Kaisen
# 15965     10                               The Apothecary Diary
# 15966      6                                         SPY×FAMILY
#
#                                                 synopsis  \
# 0      Following their participation at the Inter-Hig...
# 1      Music accompanies the path of the human metron...
# ...

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/animedataset/profiles_clean.csv'

# Specify the number of rows to read
nrows = 15000

profiles = pd.read_csv(file_path) #, nrows=nrows)

# %%
profiles_df= profiles.copy()

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/animedataset/reviews_clean.csv'

# Specify the number of rows to read
nrows = 15000

reviews = pd.read_csv(file_path, nrows=nrows)

# %%
reviews_df = reviews.copy()

# %% [markdown]
# # clean anime 23

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/final_animedataset.csv'

# Specify the number of rows to read
nrows = 200000

anime23 = pd.read_csv(file_path, nrows=nrows)

# %%
anime23['username'] = anime23['username'].replace('nami', 'Nami')

# %%
anime23=anime23.drop_duplicates()

# %%
anime23
# Out:
#         username  anime_id  my_score  user_id  gender  \
# 0           Nami        21         9  2255153  Female
# 1           Nami        59         7  2255153  Female
# 2           Nami        74         7  2255153  Female
# 3           Nami       120         7  2255153  Female
# 4           Nami       178         7  2255153  Female
# ...          ...       ...       ...      ...     ...
# 199995  Emotocon      5244         0   348264    Male
# 199996  Emotocon      5258         8   348264    Male
# 199997  Emotocon      5310         9   348264    Male
# 199998  Emotocon      6064         0   348264    Male
# 199999  Emotocon      6381         6   348264    Male
#
#                                                     title     type  \
# 0                                               One Piece       TV
# 1                                                 Chobits       TV
# 2                                            Gakuen Alice       TV
# ...

# %%
anime23.to_csv('/content/drive/MyDrive/final_animedataset.csv', index=False)

# %% [markdown]
# # All Function to use later

# %%
#correct
#use anime_df
def get_top_anime_rating(data_frame, num_anime=15):
    if data_frame is None:
        print("Error: DataFrame is None.")
        return None

    # Drop rows with missing values in the "score" column
    data_frame.dropna(subset=['score'], inplace=True)


    if data_frame.empty:
        print("Error: DataFrame is empty after dropping missing values.")
        return None

    # Sort the DataFrame by "score" in descending order
    sorted_df = data_frame.sort_values(by="score", ascending=False)

    # Select the columns "title" and "score", then drop duplicates based on the "title" column
    unique_titles_df = sorted_df[["title", "score","img_url"]].drop_duplicates("title")

    # Take the specified number of top anime titles
    top_anime_titles = unique_titles_df.head(num_anime)

    return top_anime_titles

top = get_top_anime_rating(anime_df,25)
top.reset_index(drop=True, inplace=True)

# %%
def get_top_anime_popularity(data_frame, num_anime=15):
    # Filter the DataFrame to exclude rows where the "type" column is "movie" or "Movie"
   # data_frame_notmovie = data_frame[~data_frame['type'].isin(['movie', 'Movie'])]

    #data_frame['episodes'] = pd.to_numeric(data_frame['episodes'], errors='coerce')

    # Filter rows where the "episodes" column is greater than 1
    #data_frame = data_frame[data_frame['episodes'] > 1]
    # Sort the DataFrame by "score" in descending order
    sorted_df = data_frame.sort_values(by="members", ascending=False)

    # Select the columns "title" and "score", then drop duplicates based on the "title" column
    unique_titles_df = sorted_df[["title", "members","img_url"]].drop_duplicates("title")

    # Take the specified number of top anime titles
    top_anime_titles = unique_titles_df.head(num_anime)

    return top_anime_titles

# %%
unique_genres
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f460869cdf4f> in <cell line: 1>()
# ----> 1 unique_genres
#
# NameError: name 'unique_genres' is not defined

# %%
import pandas as pd

def get_top_titles_for_genre(anime_df, genre, n_anime=20):
    # Convert the "genre" column to string
    anime_df['genre'] = anime_df['genre'].astype(str)

    # Initialize an empty list to store unique genres
    unique_genres = set()

    # Iterate over each row in the DataFrame
    for genres_str in anime_df['genre']:
        # Split the genre string by comma and add each genre to the set of unique genres
        unique_genres.update(genres_str.strip("[]").replace("'", "").split(", "))

    # Define a function to get top titles for a given genre
def get_top_titles_for_genre(anime_df, genre, n_anime=20):
    # Convert the "genre" column to string
    anime_df['genre'] = anime_df['genre'].astype(str)

    # Filter DataFrame to include only rows containing the chosen genre
    filtered_df = anime_df[anime_df['genre'].str.contains(genre)]

    # Drop duplicates from the DataFrame
    filtered_df = filtered_df.drop_duplicates(subset="title")

    # Sort by "score"
    sorted_df = filtered_df.sort_values(by="score", ascending=False)

    # Get the top titles from the sorted DataFrame
    top_titles = sorted_df.head(n_anime)[["title", "img_url"]]

    return top_titles

# %%
get_top_titles_for_genre(anime_df, "Romance", n_anime=20)
# Out:
#                                                    title  \
# 771                                        Kimi no Na wa
# 14                                   Clannad After Story
# 15965                               The Apothecary Diary
# 1                                Shigatsu wa Kimi no Uso
# 757                      Monogatari Series Second Season
# 755    Rurouni Kenshin Meiji Kenkaku Romantan  Tsuiok...
# 753    Seishun Buta Yarou wa Yumemiru Shoujo no Yume ...
# 749                                  Howl no Ugoku Shiro
# 739                        Suzumiya Haruhi no Shoushitsu
# 729                               Yojouhan Shinwa Taikei
# 727                                   Bakuman 3rd Season
# 719                        Kara no Kyoukai 5 Mujun Rasen
# 712                                          Tenki no Ko
# 700                                 No Game No Life Zero
# 688                                   Hotarubi no Mori e
# ...

# %%
def get_top_anime_by_year(anime_df, year, n_anime=10):
    # include only rows for the specified year
    filtered_df = anime_df[anime_df["start_year"] == year]

    #filtered_df = filtered_df[~filtered_df['Type'].isin(['movie', 'Movie'])]
    filtered_df = filtered_df.drop_duplicates(subset="title")

    # Sort by "Rating"
    sorted_df = filtered_df.sort_values(by="score", ascending=False)

    # return the specified number of top anime titles and image URLs
    top_anime_titles = sorted_df[["title", "img_url"]].head(n_anime)

    return top_anime_titles.values.tolist()

# %%
get_top_anime_by_year(anime_df, 2010, n_anime=10)
# Out:
#                                                  title  \
# 739                      Suzumiya Haruhi no Shoushitsu
# 697             Gintama Movie 1 Shinyaku Benizakurahen
# 516                                      Major Message
# 468                     Gintama Shinyaku Benizakurahen
# 435  Detective Conan Movie 14 The Lost Ship in the Sky
# 368                                 Eve no Jikan Movie
# 327              One Piece Film Strong World Episode 0
# 300                                  Omae Umasou da na
# 256                             Trigun Badlands Rumble
# 264                            Karigurashi no Arrietty
#
#                                                img_url
# 739  https://cdn.myanimelist.net/images/anime/2/738...
# 697  https://cdn.myanimelist.net/images/anime/4/288...
# 516  https://cdn.myanimelist.net/images/anime/11/75...
# 468  https://cdn.myanimelist.net/images/anime/12/26...
# 435  https://cdn.myanimelist.net/images/anime/7/223...
# ...

# %%
# keep using anime23
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

def find_similar_byanime(anime_name, anime_df, top_n=10):
    # Filter the anime DataFrame to get the data for the given anime
    anime_data = anime_df[~anime_df['type'].isin(['movie', 'Movie'])]
    anime_data = anime_df[anime_df["title"] == anime_name]


    if anime_data.empty:
        return "Anime not found in the anime_df."

    # Create a user-anime matrix based on the provided anime data
    user_anime_matrix = pd.pivot_table(data=anime_df,
                                       values='my_score',
                                       index='user_id',
                                       columns='anime_id',
                                       fill_value=0)

    # Compute the pairwise cosine similarity between the given anime and all other anime
    anime_vector = user_anime_matrix.loc[:, anime_data["anime_id"].values].values
    similarities = cosine_similarity(anime_vector.T, anime_vector.T)

    # Get the indices of the top N most similar anime (excluding the given anime itself)
    similar_anime_indices = similarities.argsort()[0][-2:-top_n-2:-1]

    # Get the anime IDs of the top N most similar anime
    similar_anime_ids = user_anime_matrix.columns[similar_anime_indices]

    # Get the titles of the top N most similar anime using the anime_df
    similar_anime_names = [anime_df.loc[anime_id, "title"] for anime_id in similar_anime_ids]

    return similar_anime_names

# %%
pip install surprise
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3162999 sha256=6ff4d952c1c13984c4ab868766e18c6e7d49bf3eecefbd042e237c77bb3ed037
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# ...

# %%
import pandas as pd
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
#use anime23
def get_surprise_recommendations(anime_df, user_id,num):
    # Load data into Surprise Dataset
    reader = Reader(rating_scale=(1, 10))
    data = Dataset.load_from_df(anime23[['user_id', 'anime_id', 'my_score']], reader)

    # Choose algorithm (SVD in this example)
    algo = SVD()

    # Split data into train and test sets
    trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

    # Train the model
    algo.fit(trainset)

    # Generate predictions for test set
    predictions = algo.test(testset)

    # Evaluate the model (optional)
    accuracy.rmse(predictions)

    # Load anime data into a DataFrame (assuming you have a DataFrame named 'anime_df' containing anime information)
    anime_titles = anime_df.set_index('anime_id')['title'].to_dict()

    # Get top-N recommendations for the specified user
    user_predictions = algo.test([(user_id, anime_id, 0) for anime_id in anime23['anime_id'].unique()])
    top_recommendations = [(anime_titles[pred.iid], pred.est) for pred in sorted(user_predictions, key=lambda x: x.est, reverse=True)[:num]]

    return top_recommendations

# %%
#use anime_df
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

def get_top_similar_anime_by_synopsis(anime_df, anime_name, num):
    # Define a TF-IDF Vectorizer
    tfidf = TfidfVectorizer(stop_words='english')

    # Replace NaN values with an empty string
    anime_df["synopsis"] = anime_df["synopsis"].fillna("")

    # Construct the TF-IDF matrix
    tfidf_matrix = tfidf.fit_transform(anime_df["synopsis"])

    # Compute the cosine similarity matrix
    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

    # Get the index of the anime matching the title
    idx = anime_df[anime_df['title'] == anime_name].index[0]

    # Get the pairwise similarity scores of all anime with that anime
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the anime based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the top similar anime indices
    sim_indices = [i[0] for i in sim_scores[1:num+1]]  # Exclude the first item (itself) and get top num similar

    # Return the top similar anime
    return anime_df.iloc[sim_indices][['title', 'img_url']]

# %%
def get_top_unique_genre(anime_df):
    # Convert the "genre" column to string
    anime_df['genre'] = anime_df['genre'].astype(str)
    # Initialize an empty set to store unique genres
    unique_genres = set()
    # Iterate over each row in the DataFrame
    for genres_str in anime_df['genre']:
        # Split the genre string by comma and add each genre to the set of unique genres
        genres_list = [genre.strip() for genre in genres_str.strip("[]").replace("'", "").split(",") if genre.strip()]
        unique_genres.update(genres_list)

    return sorted(list(unique_genres))  # Sort and convert set to a list for clear output

# %%
get_top_unique_genre(anime_df)
# Out:
# 'Action'

# %% [markdown]
# # Page of recomandation

# %% [markdown]
# ## Get recomandation Strimlit App

# %%
# not All function Working no image
# %%writefile Reco.py
import streamlit as st
import pandas as pd

# Load anime data
anime_df = pd.read_csv("/content/drive/MyDrive/animedataset/anime_clean.csv")
file_path = '/content/drive/MyDrive/final_animedataset.csv'
# Specify the number of rows to read
nrows = 20000
anime23 = pd.read_csv(file_path, nrows=nrows)


# Recommendation functions

def get_top_anime_rating(data_frame, num_anime=15):
    if data_frame is None:
        print("Error: DataFrame is None.")
        return None
    # Drop rows with missing values in the "score" column
    data_frame.dropna(subset=['score'], inplace=True)
    if data_frame.empty:
        print("Error: DataFrame is empty after dropping missing values.")
        return None
    # Sort the DataFrame by "score" in descending order
    sorted_df = data_frame.sort_values(by="score", ascending=False)
    # Select the columns "title" and "score", then drop duplicates based on the "title" column
    unique_titles_df = sorted_df[["title", "score","img_url"]].drop_duplicates("title")
    # Take the specified number of top anime titles
    top_anime_titles = unique_titles_df.head(num_anime)
    return top_anime_titles

#top = get_top_anime_rating(anime_df,25)
#top.reset_index(drop=True, inplace=True)



def get_top_anime_popularity(data_frame, num_anime=15):

    sorted_df = data_frame.sort_values(by="members", ascending=False)
    # Select the columns "title" and "score", then drop duplicates based on the "title" column
    unique_titles_df = sorted_df[["title", "members","img_url"]].drop_duplicates("title")
    # Take the specified number of top anime titles
    top_anime_titles = unique_titles_df.head(num_anime)
    return top_anime_titles


import pandas as pd

def get_top_unique_genre(anime_df):
    # Convert the "genre" column to string
    anime_df['genre'] = anime_df['genre'].astype(str)
    # Initialize an empty set to store unique genres
    unique_genres = set()
    # Iterate over each row in the DataFrame
    for genres_str in anime_df['genre']:
        # Split the genre string by comma and add each genre to the set of unique genres
        unique_genres.update(genres_str.strip("[]").replace("'", "").split(", "))

    return unique_genres



    # Define a function to get top titles for a given genre
def get_top_titles_for_genre(anime_df, genre, n_anime=20):
    # Convert the "genre" column to string
    anime_df['genre'] = anime_df['genre'].astype(str)
    # Filter DataFrame to include only rows containing the chosen genre
    filtered_df = anime_df[anime_df['genre'].str.contains(genre)]
    # Drop duplicates from the DataFrame
    filtered_df = filtered_df.drop_duplicates(subset="title")
    # Sort by "score"
    sorted_df = filtered_df.sort_values(by="score", ascending=False)
    # Get the top titles from the sorted DataFrame
    top_titles = sorted_df.head(n_anime)[["title", "img_url"]]

    return top_titles


def get_top_anime_by_year(anime_df, year, n_anime=10):
    # include only rows for the specified year
    filtered_df = anime_df[anime_df["start_year"] == year]
    #filtered_df = filtered_df[~filtered_df['Type'].isin(['movie', 'Movie'])]
    filtered_df = filtered_df.drop_duplicates(subset="title")
    # Sort by "Rating"
    sorted_df = filtered_df.sort_values(by="score", ascending=False)
    # return the specified number of top anime titles and image URLs as a DataFrame
    top_anime_titles = sorted_df[["title", "img_url"]].head(n_anime)

    return top_anime_titles


# keep using anime23
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

def find_similar_byanime(anime_name, anime_df, top_n=10):
    # Filter the anime DataFrame to get the data for the given anime
    anime_data = anime_df[~anime_df['type'].isin(['movie', 'Movie'])]
    anime_data = anime_df[anime_df["title"] == anime_name]


    if anime_data.empty:
        return "Anime not found in the anime_df."

    # Create a user-anime matrix based on the provided anime data
    user_anime_matrix = pd.pivot_table(data=anime_df,
                                       values='my_score',
                                       index='user_id',
                                       columns='anime_id',
                                       fill_value=0)

    # Compute the pairwise cosine similarity between the given anime and all other anime
    anime_vector = user_anime_matrix.loc[:, anime_data["anime_id"].values].values
    similarities = cosine_similarity(anime_vector.T, anime_vector.T)

    # Get the indices of the top N most similar anime (excluding the given anime itself)
    similar_anime_indices = similarities.argsort()[0][-2:-top_n-2:-1]

    # Get the anime IDs of the top N most similar anime
    similar_anime_ids = user_anime_matrix.columns[similar_anime_indices]

    # Get the titles of the top N most similar anime using the anime_df
    similar_anime_names = [anime_df.loc[anime_id, "title"] for anime_id in similar_anime_ids]

    return similar_anime_names


import pandas as pd
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
#use anime23
def get_surprise_recommendations(anime_df, user_id,num):
    # Load data into Surprise Dataset
    reader = Reader(rating_scale=(1, 10))
    data = Dataset.load_from_df(anime23[['user_id', 'anime_id', 'my_score']], reader)
    # Choose algorithm (SVD in this example)
    algo = SVD()
    # Split data into train and test sets
    trainset, testset = train_test_split(data, test_size=0.2, random_state=42)
    # Train the model
    algo.fit(trainset)
    # Generate predictions for test set
    predictions = algo.test(testset)
    # Evaluate the model (optional)
    accuracy.rmse(predictions)
    # Load anime data into a DataFrame (assuming you have a DataFrame named 'anime_df' containing anime information)
    anime_titles = anime_df.set_index('anime_id')['title'].to_dict()
    # Get top-N recommendations for the specified user
    user_predictions = algo.test([(user_id, anime_id, 0) for anime_id in anime23['anime_id'].unique()])
    top_recommendations = [(anime_titles[pred.iid], pred.est) for pred in sorted(user_predictions, key=lambda x: x.est, reverse=True)[:num]]

    return top_recommendations


#use anime_df
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
def get_top_similar_anime_by_synopsis(anime_df, anime_name, num):
    # Define a TF-IDF Vectorizer
    tfidf = TfidfVectorizer(stop_words='english')
    # Replace NaN values with an empty string
    anime_df["synopsis"] = anime_df["synopsis"].fillna("")
    # Construct the TF-IDF matrix
    tfidf_matrix = tfidf.fit_transform(anime_df["synopsis"])
    # Compute the cosine similarity matrix
    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
    # Get the index of the anime matching the title
    idx = anime_df[anime_df['title'] == anime_name].index[0]
    # Get the pairwise similarity scores of all anime with that anime
    sim_scores = list(enumerate(cosine_sim[idx]))
    # Sort the anime based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    # Get the top similar anime indices
    sim_indices = [i[0] for i in sim_scores[1:num+1]]  # Exclude the first item (itself) and get top num similar
    # Return the top similar anime
    return anime_df.iloc[sim_indices][['title', 'img_url']]


# Streamlit app
st.title("Anime Alchemist")

# Generate a unique identifier for the selectbox
selectbox_key = "choose_recommendation"

# Sidebar options
option = st.sidebar.selectbox("Choose a recommendation",
                               ["Top Rated", "Most Popular", "By Genre",
                                "By Year", "By Anime", "By Synopsis",
                                "Surprise Me"],
                               key=selectbox_key)

# Display recommendation results
if option == "Top Rated":
    top_anime = get_top_anime_rating(anime_df,10)
    top_anime.reset_index(drop=True, inplace=True)
elif option == "Most Popular":
    top_anime = get_top_anime_popularity(anime_df,10)
    top_anime.reset_index(drop=True, inplace=True)
elif option == "By Genre":
    genres = anime_df['genre'].unique()
    chosen_genre = st.sidebar.selectbox("Select a genre", genres)
    top_anime = get_top_titles_for_genre(anime_df, chosen_genre)
    top_anime.reset_index(drop=True, inplace=True)
elif option == "By Year":
    years = anime_df['start_year'].unique()
    chosen_year = st.sidebar.slider("Select a year", min(years), max(years))
    top_anime = get_top_anime_by_year(anime_df, chosen_year)
    top_anime.reset_index(drop=True, inplace=True)
elif option == "By Anime":
    anime_titles = anime_df['title'].tolist()
    chosen_anime = st.sidebar.selectbox("Select an anime", anime_titles)
    top_anime = find_similar_byanime(chosen_anime, anime23,10)
    top_anime.reset_index(drop=True, inplace=True)
elif option == "By Synopsis":
    anime_titles = anime_df['title'].tolist()
    chosen_anime = st.sidebar.selectbox("Select an anime", anime_titles)
    top_anime = get_top_similar_anime_by_synopsis(anime_df, chosen_anime)
    top_anime.reset_index(drop=True, inplace=True)
elif option == "Surprise Me":
    user_id = st.sidebar.text_input("Enter your user ID")
    num = st.sidebar.slider("Number of recommendations", 1, 10)
    top_anime = get_surprise_recommendations(anime23, user_id, num)
    top_anime.reset_index(drop=True, inplace=True)

# Display top anime recommendations
if top_anime is not None:
    for index, anime in top_anime.iterrows():
        st.write(anime['title'], anime['img_url'])  # Display title and img_url
# Out:
# Writing Reco.py

# %% [markdown]
# ## Correct year and genre

# %%
# correct year and genre
# %%writefile Reco.py
import streamlit as st
import pandas as pd
import datetime

# Load anime data
anime_df = pd.read_csv("/content/drive/MyDrive/animedataset/anime_clean.csv")
file_path = '/content/drive/MyDrive/final_animedataset.csv'
# Specify the number of rows to read
nrows = 20000
anime23 = pd.read_csv(file_path, nrows=nrows)
# Get the current year
current_year = datetime.datetime.now().year

# Generate a list of years from 1959 to the current year
years = list(range(1959, current_year + 1))

# Recommendation functions

def get_top_anime_rating(data_frame, num_anime=15):
    if data_frame is None:
        print("Error: DataFrame is None.")
        return None
    # Drop rows with missing values in the "score" column
    data_frame.dropna(subset=['score'], inplace=True)
    if data_frame.empty:
        print("Error: DataFrame is empty after dropping missing values.")
        return None
    # Sort the DataFrame by "score" in descending order
    sorted_df = data_frame.sort_values(by="score", ascending=False)
    # Select the columns "title" and "score", then drop duplicates based on the "title" column
    unique_titles_df = sorted_df[["title", "score","img_url"]].drop_duplicates("title")
    # Take the specified number of top anime titles
    top_anime_titles = unique_titles_df.head(num_anime)
    return top_anime_titles

#top = get_top_anime_rating(anime_df,25)
#top.reset_index(drop=True, inplace=True)



def get_top_anime_popularity(data_frame, num_anime=15):

    sorted_df = data_frame.sort_values(by="members", ascending=False)
    # Select the columns "title" and "score", then drop duplicates based on the "title" column
    unique_titles_df = sorted_df[["title", "members","img_url"]].drop_duplicates("title")
    # Take the specified number of top anime titles
    top_anime_titles = unique_titles_df.head(num_anime)
    return top_anime_titles


import pandas as pd

def get_top_unique_genre(anime_df):
    # Convert the "genre" column to string
    anime_df['genre'] = anime_df['genre'].astype(str)
    # Initialize an empty set to store unique genres
    unique_genres = set()
    # Iterate over each row in the DataFrame
    for genres_str in anime_df['genre']:
        # Split the genre string by comma and add each genre to the set of unique genres
        genres_list = [genre.strip() for genre in genres_str.strip("[]").replace("'", "").split(",") if genre.strip()]
        unique_genres.update(genres_list)

    return sorted(list(unique_genres))  # Sort and convert set to a list for clear output




    # Define a function to get top titles for a given genre
def get_top_titles_for_genre(anime_df, genre, n_anime=20):
    # Convert the "genre" column to string
    anime_df['genre'] = anime_df['genre'].astype(str)
    # Filter DataFrame to include only rows containing the chosen genre
    filtered_df = anime_df[anime_df['genre'].str.contains(genre)]
    # Drop duplicates from the DataFrame
    filtered_df = filtered_df.drop_duplicates(subset="title")
    # Sort by "score"
    sorted_df = filtered_df.sort_values(by="score", ascending=False)
    # Get the top titles from the sorted DataFrame
    top_titles = sorted_df.head(n_anime)[["title", "img_url"]]

    return top_titles


def get_top_anime_by_year(anime_df, year, n_anime=10):
    # include only rows for the specified year
    filtered_df = anime_df[anime_df["start_year"] == year]
    #filtered_df = filtered_df[~filtered_df['Type'].isin(['movie', 'Movie'])]
    filtered_df = filtered_df.drop_duplicates(subset="title")
    # Sort by "Rating"
    sorted_df = filtered_df.sort_values(by="score", ascending=False)
    # return the specified number of top anime titles and image URLs as a DataFrame
    top_anime_titles = sorted_df[["title", "img_url"]].head(n_anime)

    return top_anime_titles


# keep using anime23
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

def find_similar_byanime(anime_name, anime_df, top_n=10):
    # Filter the anime DataFrame to get the data for the given anime
    anime_data = anime_df[~anime_df['type'].isin(['movie', 'Movie'])]
    anime_data = anime_df[anime_df["title"] == anime_name]


    if anime_data.empty:
        return "Anime not found in the anime_df."

    # Create a user-anime matrix based on the provided anime data
    user_anime_matrix = pd.pivot_table(data=anime_df,
                                       values='my_score',
                                       index='user_id',
                                       columns='anime_id',
                                       fill_value=0)

    # Compute the pairwise cosine similarity between the given anime and all other anime
    anime_vector = user_anime_matrix.loc[:, anime_data["anime_id"].values].values
    similarities = cosine_similarity(anime_vector.T, anime_vector.T)

    # Get the indices of the top N most similar anime (excluding the given anime itself)
    similar_anime_indices = similarities.argsort()[0][-2:-top_n-2:-1]

    # Get the anime IDs of the top N most similar anime
    similar_anime_ids = user_anime_matrix.columns[similar_anime_indices]

    # Get the titles of the top N most similar anime using the anime_df
    similar_anime_names = [anime_df.loc[anime_id, "title"] for anime_id in similar_anime_ids]

    return similar_anime_names


import pandas as pd
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
#use anime23
def get_surprise_recommendations(anime_df, user_id,num):
    # Load data into Surprise Dataset
    reader = Reader(rating_scale=(1, 10))
    data = Dataset.load_from_df(anime23[['user_id', 'anime_id', 'my_score']], reader)
    # Choose algorithm (SVD in this example)
    algo = SVD()
    # Split data into train and test sets
    trainset, testset = train_test_split(data, test_size=0.2, random_state=42)
    # Train the model
    algo.fit(trainset)
    # Generate predictions for test set
    predictions = algo.test(testset)
    # Evaluate the model (optional)
    accuracy.rmse(predictions)
    # Load anime data into a DataFrame (assuming you have a DataFrame named 'anime_df' containing anime information)
    anime_titles = anime_df.set_index('anime_id')['title'].to_dict()
    # Get top-N recommendations for the specified user
    user_predictions = algo.test([(user_id, anime_id, 0) for anime_id in anime23['anime_id'].unique()])
    top_recommendations = [(anime_titles[pred.iid], pred.est) for pred in sorted(user_predictions, key=lambda x: x.est, reverse=True)[:num]]

    return top_recommendations


#use anime_df
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
def get_top_similar_anime_by_synopsis(anime_df, anime_name, num):
    # Define a TF-IDF Vectorizer
    tfidf = TfidfVectorizer(stop_words='english')
    # Replace NaN values with an empty string
    anime_df["synopsis"] = anime_df["synopsis"].fillna("")
    # Construct the TF-IDF matrix
    tfidf_matrix = tfidf.fit_transform(anime_df["synopsis"])
    # Compute the cosine similarity matrix
    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
    # Get the index of the anime matching the title
    idx = anime_df[anime_df['title'] == anime_name].index[0]
    # Get the pairwise similarity scores of all anime with that anime
    sim_scores = list(enumerate(cosine_sim[idx]))
    # Sort the anime based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    # Get the top similar anime indices
    sim_indices = [i[0] for i in sim_scores[1:num+1]]  # Exclude the first item (itself) and get top num similar
    # Return the top similar anime
    return anime_df.iloc[sim_indices][['title', 'img_url']]


# Streamlit app
st.title("Anime Alchemist")

# Generate a unique identifier for the selectbox
selectbox_key = "choose_recommendation"

# Sidebar options
option = st.sidebar.selectbox("Choose a recommendation",
                               ["Top Rated", "Most Popular", "By Genre",
                                "By Year", "By Anime", "By Synopsis",
                                "Surprise Me"],
                               key=selectbox_key)

# Display recommendation results
if option == "Top Rated":
    top_anime = get_top_anime_rating(anime_df,10)
    top_anime.reset_index(drop=True, inplace=True)
elif option == "Most Popular":
    top_anime = get_top_anime_popularity(anime_df,10)
    top_anime.reset_index(drop=True, inplace=True)
elif option == "By Genre":
    genres = get_top_unique_genre(anime_df)  # Use get_top_unique_genre function to get unique genres
    chosen_genre = st.sidebar.selectbox("Select a genre", genres)
    top_anime = get_top_titles_for_genre(anime_df, chosen_genre)
    top_anime.reset_index(drop=True, inplace=True)


# Sidebar options
if option == "By Year":
    chosen_year = st.sidebar.selectbox("Select a year", years)
    top_anime = get_top_anime_by_year(anime_df, chosen_year)
    top_anime.reset_index(drop=True, inplace=True)
elif option == "By Anime":
    anime_titles = anime_df['title'].tolist()
    chosen_anime = st.sidebar.selectbox("Select an anime", anime_titles)
    top_anime = find_similar_byanime(chosen_anime, anime23,10)
    top_anime.reset_index(drop=True, inplace=True)
elif option == "By Synopsis":
    anime_titles = anime_df['title'].tolist()
    chosen_anime = st.sidebar.selectbox("Select an anime", anime_titles)
    top_anime = get_top_similar_anime_by_synopsis(anime_df, chosen_anime, 15)
    top_anime.reset_index(drop=True, inplace=True)
elif option == "Surprise Me":
    user_id = st.sidebar.text_input("Enter your user ID")
    num = st.sidebar.slider("Number of recommendations", 1, 10)
    top_anime = get_surprise_recommendations(anime23, user_id, num)
    top_anime.reset_index(drop=True, inplace=True)

# Display top anime recommendations
if top_anime is not None:
    for index, anime in top_anime.iterrows():
        st.write(anime['title'], anime['img_url'])  # Display title and img_url
# Out:
# Overwriting Reco.py

# %%
# !streamlit run Reco.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.145.11.42
# npx: installed 22 in 2.955s
# your url is: https://plenty-trees-dream.loca.lt

# %%
anime_df
# Out:
#          uid                                              title  \
# 0      28891                              Haikyuu Second Season
# 1      23273                            Shigatsu wa Kimi no Uso
# 2      34599                                      Made in Abyss
# 3       5114                    Fullmetal Alchemist Brotherhood
# 4      31758                     Kizumonogatari III Reiketsuhen
# ...      ...                                                ...
# 15962  16934  Chuunibyou demo Koi ga Shitai Kirameki no Slap...
# 15963      2                                       Demon Slayer
# 15964      3                                     Jujutsu Kaisen
# 15965     10                               The Apothecary Diary
# 15966      6                                         SPY×FAMILY
#
#                                                 synopsis  \
# 0      Following their participation at the Inter-Hig...
# 1      Music accompanies the path of the human metron...
# ...

# %% [markdown]
# ## try to import function

# %%
# !cp /content/drive/MyDrive/functions.py /content

# %%
# correct function
# %%writefile Reco1.py
import streamlit as st
import pandas as pd
import datetime
from surprise import Reader
from sklearn.metrics.pairwise import cosine_similarity
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import functions


# Load anime data
anime_df = pd.read_csv("/content/drive/MyDrive/animedataset/anime_clean.csv")
file_path = '/content/drive/MyDrive/final_animedataset.csv'
# Specify the number of rows to read
nrows = 200000
anime23 = pd.read_csv(file_path, nrows=nrows)
#reset indextation since working with a sample
#anime23.reset_index(drop=True, inplace=True)
# Get the current year
current_year = datetime.datetime.now().year

# Generate a list of years from 1959 to the current year
years = list(range(1959, current_year + 1))

# keep using anime23
def find_similar_byanime(anime_name, anime_df, top_n=10):
    # Filter the anime DataFrame to get the data for the given anime
    anime_data = anime_df[~anime_df['type'].isin(['movie', 'Movie'])]
    anime_data = anime_data[anime_data["title"] == anime_name]

    if anime_data.empty:
        return pd.DataFrame(columns=["title", "img_url"])  # Return an empty DataFrame

    # Create a user-anime matrix based on the provided anime data
    user_anime_matrix = pd.pivot_table(data=anime_df,
                                       values='my_score',
                                       index='user_id',
                                       columns='anime_id',
                                       fill_value=0)

    # Compute the pairwise cosine similarity between the given anime and all other anime
    anime_vector = user_anime_matrix.loc[:, anime_data["anime_id"].values].values
    similarities = cosine_similarity(anime_vector.T, anime_vector.T)

    # Get the indices of the top N most similar anime (excluding the given anime itself)
    similar_anime_indices = similarities.argsort()[0][-2:-top_n-2:-1]

    # Get the anime IDs of the top N most similar anime
    similar_anime_ids = user_anime_matrix.columns[similar_anime_indices]

    # Get the titles of the top N most similar anime using the anime_df
    similar_anime_names = [anime_df.loc[anime_id, "title"] for anime_id in similar_anime_ids]

    # Create a DataFrame with similar anime titles and their image URLs
    similar_anime_df = pd.DataFrame({
        "title": similar_anime_names,
        "img_url": ""  # You can add the image URLs here if available
    })

    return similar_anime_df

import pandas as pd

def get_surprise_recommendations(anime_df, user_id, num):
    # Load data into Surprise Dataset
    reader = Reader(rating_scale=(1, 10))
    data = Dataset.load_from_df(anime_df[['user_id', 'anime_id', 'my_score']], reader)

    # Choose algorithm (SVD in this example)
    algo = SVD()

    # Split data into train and test sets
    trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

    # Train the model
    algo.fit(trainset)

    # Generate predictions for test set
    predictions = algo.test(testset)

    # Evaluate the model (optional)
    accuracy.rmse(predictions)

    # Load anime data into a DataFrame (assuming you have a DataFrame named 'anime_df' containing anime information)
    anime_data = anime_df.set_index('anime_id')  # Set anime_id as index for easier lookup

    # Get top-N recommendations for the specified user
    user_predictions = algo.test([(user_id, anime_id, 0) for anime_id in anime_df['anime_id'].unique()])
    top_recommendations = []
    for pred in sorted(user_predictions, key=lambda x: x.est, reverse=True)[:num]:
        anime_id = pred.iid
        title = anime_data.loc[anime_id, 'title']
        top_recommendations.append({'title': title})

    # Create a DataFrame with recommendations and placeholder columns for image URLs
    recommendations_df = pd.DataFrame(top_recommendations)
    recommendations_df['img_url'] = ""  # Placeholder for image URLs

    return recommendations_df


# Streamlit app
st.title("Anime Alchemist")

# Generate a unique identifier for the selectbox
selectbox_key = "choose_recommendation"

# Sidebar options
option = st.sidebar.selectbox("Choose a recommendation",
                               ["Top Rated", "Most Popular", "By Genre",
                                "By Year", "By Anime", "By Story",
                                "Surprise Me"],
                               key=selectbox_key)

# Display recommendation results
if option == "Top Rated":
    top_anime = functions.get_top_anime_rating(anime_df,10)
    top_anime.reset_index(drop=True, inplace=True)

elif option == "Most Popular":
    top_anime = functions.get_top_anime_popularity(anime_df,10)
    top_anime.reset_index(drop=True, inplace=True)

elif option == "By Genre":
    genres = functions.get_top_unique_genre(anime_df)  # Use get_top_unique_genre function to get unique genres
    chosen_genre = st.sidebar.selectbox("Select a genre", genres)
    top_anime = functions.get_top_titles_for_genre(anime_df, chosen_genre)
    top_anime.reset_index(drop=True, inplace=True)

if option == "By Year":
    chosen_year = st.sidebar.selectbox("Select a year", years)
    top_anime = functions.get_top_anime_by_year(anime_df, chosen_year)
    top_anime.reset_index(drop=True, inplace=True)

elif option == "By Anime":
    anime_titles = anime_df['title'].tolist()
    chosen_anime = st.sidebar.selectbox("Select an anime", anime_titles)
    top_anime = find_similar_byanime(chosen_anime, anime23,10)
    #top_anime.reset_index(drop=True, inplace=True)

elif option == "By Story":
    anime_titles = anime_df['title'].tolist()
    chosen_anime = st.sidebar.selectbox("Select an anime", anime_titles)
    top_anime = functions.get_top_similar_anime_by_synopsis(anime_df, chosen_anime, 15)
    top_anime.reset_index(drop=True, inplace=True)

elif option == "Surprise Me":
    user_id = st.sidebar.text_input("Enter your user ID")
    num = st.sidebar.slider("Number of recommendations", 1, 10)
    top_anime = get_surprise_recommendations(anime23, user_id, num)
    #top_anime.reset_index(drop=True, inplace=True)

# Display top anime recommendations
if top_anime is not None:
    for index, anime in top_anime.iterrows():
        st.write(anime['title'], anime['img_url'])  # Display title and img_url
# Out:
# Overwriting Reco1.py

# %%
anime23.reset_index(drop=True, inplace=True)

# %%
# !streamlit run Reco1.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.41.212.152
# npx: installed 22 in 5.69s
# your url is: https://honest-peaches-sneeze.loca.lt

# %%
anime23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   username    200000 non-null  object
#  1   anime_id    200000 non-null  int64
#  2   my_score    200000 non-null  int64
#  3   user_id     200000 non-null  int64
#  4   gender      200000 non-null  object
#  5   title       200000 non-null  object
#  6   type        200000 non-null  object
#  7   source      200000 non-null  object
#  8   score       200000 non-null  float64
#  9   scored_by   200000 non-null  int64
#  10  rank        195246 non-null  float64
#  11  popularity  200000 non-null  int64
#  12  genre       199984 non-null  object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 19.8+ MB

# %%
# !streamlit run Reco1.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.41.212.152
# npx: installed 22 in 5.69s
# your url is: https://honest-peaches-sneeze.loca.lt

# %% [markdown]
# ## Try to display the images

# %%
# correct image
# %%writefile Reco2.py
import streamlit as st
import pandas as pd
import datetime
from surprise import Reader
from sklearn.metrics.pairwise import cosine_similarity
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import functions


# Load anime data
anime_df = pd.read_csv("/content/drive/MyDrive/animedataset/anime_clean.csv")
file_path = '/content/drive/MyDrive/final_animedataset.csv'
# Specify the number of rows to read
nrows = 200000
anime23 = pd.read_csv(file_path, nrows=nrows)

# Get the current year
current_year = datetime.datetime.now().year

# Generate a list of years from 1959 to the current year
years = list(range(1959, current_year + 1))
top_anime = None

def get_surprise_recommendations(anime_df, user_name, num):
    # Check if the user name exists in the DataFrame
    if user_name not in anime_df['username'].unique():
        return "User not found in the anime_df."

    # Load data into Surprise Dataset
    reader = Reader(rating_scale=(1, 10))
    data = Dataset.load_from_df(anime_df[['user_id', 'anime_id', 'my_score']], reader)

    # Choose algorithm (SVD in this example)
    algo = SVD()

    # Split data into train and test sets
    trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

    # Train the model
    algo.fit(trainset)

    # Generate predictions for test set
    predictions = algo.test(testset)

    # Evaluate the model (optional)
    rmse = accuracy.rmse(predictions)
    st.write(f"Root Mean Squared Error (RMSE): {rmse}")

    # Get user ID based on user name
    user_id = anime_df.loc[anime_df['username'] == user_name, 'user_id'].iloc[0]

    # Get top-N recommendations for the specified user
    user_predictions = algo.test([(user_id, anime_id, 0) for anime_id in anime_df['anime_id'].unique()])
    top_recommendations = []
    for pred in sorted(user_predictions, key=lambda x: x.est, reverse=True)[:num]:
        anime_id = pred.iid
        titles = anime_df.loc[anime_df['anime_id'] == anime_id, 'title'].tolist()
        rating = round(pred.est, 1)
        # Append each title along with the rating
    for title in titles:
        top_recommendations.append((title, rating))

    return top_recommendations




# Streamlit app
st.markdown(
    "<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>",
    unsafe_allow_html=True
)

# Generate a unique identifier for the selectbox
selectbox_key = "choose_recommendation"

# Sidebar options
option = st.sidebar.selectbox("Choose a recommendation",
                               ["Top Rated", "Most Popular", "By Genre",
                                "By Year", "By Anime", "By Story",
                                "Surprise Me"],
                               key=selectbox_key)

# Display recommendation results
if option == "Top Rated":
    top_anime = functions.get_top_anime_rating(anime_df, 10)
    top_anime.reset_index(drop=True, inplace=True)

elif option == "Most Popular":
    top_anime = functions.get_top_anime_popularity(anime_df, 10)
    top_anime.reset_index(drop=True, inplace=True)

elif option == "By Genre":
    genres = functions.get_top_unique_genre(anime_df)  # Use get_top_unique_genre function to get unique genres
    chosen_genre = st.sidebar.selectbox("Select a genre", genres)
    top_anime = functions.get_top_titles_for_genre(anime_df, chosen_genre)
    top_anime.reset_index(drop=True, inplace=True)

if option == "By Year":
    chosen_year = st.sidebar.selectbox("Select a year", years)
    top_anime = functions.get_top_anime_by_year(anime_df, chosen_year)
    top_anime.reset_index(drop=True, inplace=True)

elif option == "By Anime":
    anime_titles = anime_df['title'].tolist()
    chosen_anime = st.sidebar.selectbox("Select an anime", anime_titles)
    top_anime = functions.find_similar_byanime(chosen_anime, anime23, 10)
    # top_anime.reset_index(drop=True, inplace=True)

elif option == "By Story":
    anime_titles = anime_df['title'].tolist()
    chosen_anime = st.sidebar.selectbox("Select an anime", anime_titles)
    top_anime = functions.get_top_similar_anime_by_synopsis(anime_df, chosen_anime, 15)
    top_anime.reset_index(drop=True, inplace=True)

elif option == "Surprise Me":
    user_name = st.sidebar.text_input("Enter your username")
    num = st.sidebar.slider("Number of recommendations", 1, 10)

    if user_name:
        recommendations = functions.get_surprise_recommendations(anime23, user_name, num)
        if isinstance(recommendations, str):
            st.write(recommendations)  # Display error message
        else:
            # Display top anime recommendations as a simple list
            st.write("**Top Recommendations:**")
            for idx, (title, rating) in enumerate(recommendations, start=1):
                st.write(f"{idx}. {title}: {rating}/10")
    else:
        st.write("Please enter a username to get Surprise Me recommendations.")



# Display top anime recommendations if available
if top_anime is not None:
    for index, anime in top_anime.iterrows():
        if anime['img_url']:
            st.image(anime['img_url'], caption=anime['title'], width=150)
        else:
            st.write(anime['title'])
# Out:
# Overwriting Reco2.py

# %%
anime23.sample(10)
# Out:
#               username  anime_id  my_score  user_id  gender  \
# 3844     MistButterfly     28211         5  2485327  Female
# 88790       ferranet13     28851         8  5445037    Male
# 193069    indyelmo0902      1637         0    60654  Female
# 3601     MistButterfly      6964         5  2485327  Female
# 153942  IntroverTurtle      1471         7   403117    Male
# 174411       KarenDran       437         7    43320  Female
# 78647     Duke_On_Tree      2994        10  4112031    Male
# 33773           Xephia      3667         0   117438  Female
# 21797         Sirdante      6050         8    14013    Male
# 150891          SenNen      2025         9   279435  Female
#
#                                             title     type    source  score  \
# 3844                                      Harmony    Movie     Novel   7.10
# 88790                              Koe no Katachi    Movie     Manga   9.04
# ...

# %%
# !streamlit run Reco2.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.42.183.72
# npx: installed 22 in 3.883s
# your url is: https://eager-memes-invent.loca.lt

# %% [markdown]
# #Second page generale after the log in

# %%
# %%writefile animap.py
import streamlit as st
import pandas as pd
import functions


# Load anime DataFrame
file_path = '/content/drive/MyDrive/animedataset/anime_clean.csv'
anime_df = pd.read_csv(file_path)
user_name = "Nami"

# Display welcome message with user name in light red color
st.write(f"<p style='font-size: 24px; color: #FF9999;'>Welcome back {user_name}!</p>", unsafe_allow_html=True)

# Define Streamlit app layout
st.write("<h1 style='color:blue;'>Anime Alchemist</h1>", unsafe_allow_html=True)

# Display image at the top
st.image("/content/drive/MyDrive/anime.jpg", use_column_width=True)


st.sidebar.markdown("<h2 style='text-align: center;'>Features</h2>", unsafe_allow_html=True)
get_recommendation = st.sidebar.button("Get Recommendation")
playlist = st.sidebar.button(f"{user_name}'s Playlist")
chat_with_netero = st.sidebar.button("Chat with Netero")

# Display Choice for you
st.header(f"Anime you may also like {user_name} ! ")
top_choice = functions.get_top_anime_rating_popularity(anime_df, num_anime=15, num_top=1000)
for index, row in top_choice.iterrows():
    st.image(row['img_url'], caption=row['title'], width=120)
# Out:
# Writing animap.py

# %%
# !streamlit run animap.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.42.183.72
# npx: installed 22 in 3.526s
# your url is: https://angry-tools-check.loca.lt

# %% [markdown]
# # Login Page

# %%
csv_file_path = '/content/drive/MyDrive/user_data.csv'

# Load CSV into DataFrame
user_df = pd.read_csv(csv_file_path)

# %%
user_df.to_csv('/content/drive/MyDrive/user_data.csv', index=False)

# %%
# %%writefile Animeapp2.py
import pandas as pd
import streamlit as st
import functions
csv_file_path = '/content/drive/MyDrive/user_data.csv'

# Load CSV into DataFrame
user_df = pd.read_csv(csv_file_path)
user_df['password'] = user_df['password'].astype(str)

def login(user_df):
    mail = st.text_input('Email', key='login-email')
    password = st.text_input('Password', type='password', key='login-password')

    if st.button('Login'):
        match_condition = ((user_df['mail'] == mail) & (user_df['password'] == password))

        if match_condition.any():
            st.success("Login successful!")
            # Return the username if the login is successful
            return user_df.loc[match_condition, 'user_name'].iloc[0]
        else:
            st.error("Invalid email or password. Please try again.")


def main():
    csv_file_path = '/content/drive/MyDrive/user_data.csv'  # Define the CSV file path

    #st.write("<h1 style='color:blue;'>The Anime Alchemist</h1>", unsafe_allow_html=True)

    st.markdown(
        "<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>",
        unsafe_allow_html=True
    )



    menu = st.sidebar.selectbox('Menu', ['Login', 'Create Account'])

    if menu == 'Login':
        st.title('Login Here !')
        # Call the login function and store the username
        user_name = login(user_df)
        if user_name:
            st.write(f"Welcome, {user_name}!")
            # Continue with the rest of your application
    elif menu == 'Create Account':
        st.title('join us !')
        return_to_login = functions.create_account(csv_file_path)  # Pass csv_file_path here

        # Redirect to login page if return button is clicked
        if return_to_login:
            # Call the login function and store the username
            user_name = login(user_df)
            if user_name:
                st.write(f"Welcome, {user_name}!")
                # Continue with the rest of your application

if __name__ == '__main__':
    # Load CSV into DataFrame
    user_df = pd.read_csv('/content/drive/MyDrive/user_data.csv')
    user_df['password'] = user_df['password'].astype(str)
    main()
# Out:
# Overwriting Animeapp2.py

# %%
# !streamlit run Animeapp2.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.42.183.72
# npx: installed 22 in 4.533s
# your url is: https://good-signs-drive.loca.lt

# %% [markdown]
# # List and reccomandation page

# %% [markdown]
# ## simple info display

# %%
# simple Working
# %%writefile Appinfo.py
import streamlit as st
import pandas as pd

# Define the function to display anime information and image
def display_info(selected_anime, anime_df):
    anime_info = anime_df[anime_df['title'] == selected_anime]
    title = anime_info['title'].iloc[0]
    genre = anime_info['genre'].iloc[0]
    episodes = anime_info['episodes'].iloc[0]
    score = anime_info['score'].iloc[0]
    synopsis = anime_info['synopsis'].iloc[0]
    img_url = anime_info['img_url'].iloc[0]
    link = anime_info['link'].iloc[0]

     # Display anime image
    st.image(img_url, caption=title, width=150)  # Adjust width as needed

    # Display anime information
    st.write(f"**Title:** {title}")
    st.write(f"**Genre:** {genre}")
    st.write(f"**Episodes:** {episodes}")
    st.write(f"**Score:** {score}")
    st.write(f"**Synopsis:** {synopsis}")
    st.write(f"**watch here :** {link}")


# Load anime data
anime_df = pd.read_csv("/content/drive/MyDrive/animedataset/anime_clean.csv")  # Update with the path to your anime data file

# Create a dropdown list of anime titles
anime_titles = anime_df['title'].tolist()
selected_anime = st.selectbox("Select Anime:", anime_titles)

# Display anime information and image when an anime is selected
if selected_anime:
    display_info(selected_anime, anime_df)
# Out:
# Overwriting Appinfo.py

# %%
# !streamlit run Appinfo.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.42.183.72
# npx: installed 22 in 3.128s
# your url is: https://nasty-ends-wish.loca.lt

# %%
anime_23
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-668557953963> in <cell line: 1>()
# ----> 1 anime_23
#
# NameError: name 'anime_23' is not defined

# %% [markdown]
# ## try with list and rating

# %%
# %%writefile Appinfo.py
import streamlit as st
import pandas as pd

# Define the function to display anime information and image
def display_info(selected_anime, anime_df, user_df):
    anime_info = anime_df[anime_df['title'] == selected_anime]
    title = anime_info['title'].iloc[0]
    genre = anime_info['genre'].iloc[0]
    episodes = anime_info['episodes'].iloc[0]
    score = anime_info['score'].iloc[0]
    synopsis = anime_info['synopsis'].iloc[0]
    img_url = anime_info['img_url'].iloc[0]  # Assuming 'img_url' column contains image URLs

    # Display anime information
    st.write(f"**Title:** {title}")
    st.write(f"**Genre:** {genre}")
    st.write(f"**Episodes:** {episodes}")
    st.write(f"**Score:** {score}")
    st.write(f"**Synopsis:** {synopsis}")

    # Display anime image
    st.image(img_url, caption=title, width=300)  # Adjust width as needed

    # Provide options for rating, adding to My List, and accessing My List
    rating = st.selectbox("Rate this anime (1-10)", list(range(1, 11)))
    add_to_list = st.button("Add to My List")
    view_my_list = st.button("View My List")

    # Process user actions
    if rating:
        st.write(f"You rated '{title}' as: {rating}/10")

    if add_to_list:
        st.write(f"'{title}' added to My List")

        add_to_user_list(selected_anime, user_df)  # Call function to add anime to user's list
        user_df.to_csv('/content/drive/MyDrive/user_data.csv', index=False)

    if view_my_list:
    # Reload user data from the CSV file
        user_df = pd.read_csv('/content/drive/MyDrive/user_data.csv')  # Update with the correct path

    # Display the user's list of anime
        st.write("Viewing My List...")
        if not user_df.empty:
            st.write(user_df[['user_name', 'list']])
        else:
            st.write("Your list is empty.")


# Function to add anime to user's list
def add_to_user_list(selected_anime, user_df):
    # Get the user's ID (assuming user is logged in)
    user_id = 1  # Replace with the actual user ID

    # Find the index of the user in user_df
    user_index = user_df[user_df['user_id'] == user_id].index[0]

    # Add the selected anime to the user's list
    user_df.at[user_index, 'list'].append(selected_anime)

# Load anime and user data
anime_df = pd.read_csv("/content/drive/MyDrive/animedataset/anime_clean.csv")  # Update with the path to your anime data file
user_df = pd.read_csv('/content/drive/MyDrive/user_data.csv')  # Update with the path to your user data file

st.markdown(
    "<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>",
    unsafe_allow_html=True
)

# Create a dropdown list of anime titles
anime_titles = anime_df['title'].tolist()
selected_anime = st.selectbox("Select Anime:", anime_titles)

# Display anime information and options when an anime is selected
if selected_anime:
    functions.display_info(functions.selected_anime, anime_df, user_df)
# Out:
# Overwriting Appinfo.py

# %%
user_list = pd.DataFrame(columns=['user_name', 'title', 'img_url', 'rating'])

# %%
user_list.to_csv('/content/drive/MyDrive/user_list.csv', index=False)

# %%
user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')

# %%
user_list
# Out:
#   user_name                  title  \
# 0      Nami  Haikyuu Second Season
# 1      Nami      Mob Psycho 100 II
#
#                                              img_url  rating
# 0  https://cdn.myanimelist.net/images/anime/9/766...       1
# 1  https://cdn.myanimelist.net/images/anime/1918/...       5

# %%
#The Working one
# with new use_list
# %%writefile Appinfo.py
import streamlit as st
import pandas as pd
import functions
# Load the user_list
user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')

# Load anime and user data
anime_df = pd.read_csv("/content/drive/MyDrive/animedataset/anime_clean.csv")  # Update with the path to your anime data file
user_df = pd.read_csv('/content/drive/MyDrive/user_data.csv')  # Update with the path to your user data file

st.markdown(
    "<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>",
    unsafe_allow_html=True
      )

# Function to add anime to user's list
def add_to_user_list(user_name, title, img_url, rating):
    global user_list

    # Check if user_list is empty or does not exist
    if user_list.empty:
        # Create a new DataFrame with the new row
        user_list = pd.DataFrame({'user_name': [user_name], 'title': [title], 'img_url': [img_url], 'rating': [rating]})
    else:
        # Concatenate the new row to user_list
        new_row = pd.DataFrame({'user_name': [user_name], 'title': [title], 'img_url': [img_url], 'rating': [rating]})
        user_list = pd.concat([user_list, new_row], ignore_index=True)

    # Save user_list to CSV file
    user_list.to_csv('/content/drive/MyDrive/user_list.csv', index=False)


# Function to display user's list
def display_user_list(user_name):
    global user_list
    user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')  # Reload user_list from CSV

    st.write(f"Viewing My List for {user_name}...")

    # Filter user_list for the specified user_name
    user_list_filtered = user_list[user_list['user_name'] == user_name]

    # Display titles and images
    if not user_list_filtered.empty:
        for index, row in user_list_filtered.iterrows():
            st.image(row['img_url'], caption=row['title'], width=150)
            st.write(f"**Title:** {row['title']}")
            st.write(f"**Rating:** {row['rating']}")
    else:
        st.write("Your list is empty.")





# Function to display anime information and options
def display_info(selected_anime, anime_df, user_df,user_name):
    anime_info = anime_df[anime_df['title'] == selected_anime]
    title = anime_info['title'].iloc[0]
    genre = anime_info['genre'].iloc[0]
    episodes = anime_info['episodes'].iloc[0]
    score = anime_info['score'].iloc[0]
    synopsis = anime_info['synopsis'].iloc[0]
    img_url = anime_info['img_url'].iloc[0]

    # Display anime image
    st.image(img_url, caption=title, width=300)  # Adjust width
    # Display anime information
    st.write(f"**Title:** {title}")
    st.write(f"**Genre:** {genre}")
    st.write(f"**Episodes:** {episodes}")
    st.write(f"**Score:** {score}")
    st.write(f"**Synopsis:** {synopsis}")



    # Provide options for rating, adding to My List, and accessing My List
    rating = st.selectbox("Rate this anime (1-10)", list(range(1, 11)))
    add_to_list = st.button("Add to My List")
    view_my_list = st.button("View My List")

    # Process user actions
    if rating:
        st.write(f"You rated '{title}' as: {rating}/10")

    if add_to_list:
        st.write(f"'{title}' added to My List")

        # Add anime to user's list
        add_to_user_list(user_name, selected_anime, img_url, rating)  # Call function to add anime to user's list

    if view_my_list:
        # Display user's list
        display_user_list(user_name)

user_name = "Nami"  # Replace this with the actual user name obtained from the login page

# Create a dropdown list of anime titles
anime_titles = anime_df['title'].tolist()
selected_anime = st.selectbox("Select Anime:", anime_titles)

# Display anime information and options when an anime is selected
if selected_anime:
    display_info(selected_anime, anime_df, user_df, user_name)
# Out:
# Overwriting Appinfo.py

# %%
# !streamlit run Appinfo.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.42.183.72
# npx: installed 22 in 5.457s
# your url is: https://wild-coins-accept.loca.lt

# %%
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15967 entries, 0 to 15966
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   uid         15967 non-null  int64
#  1   title       15966 non-null  object
#  2   synopsis    15963 non-null  object
#  3   genre       15967 non-null  object
#  4   aired       15967 non-null  object
#  5   episodes    15967 non-null  object
#  6   members     15967 non-null  int64
#  7   popularity  15967 non-null  int64
#  8   ranked      15967 non-null  object
#  9   score       15967 non-null  float64
#  10  img_url     15967 non-null  object
#  11  link        15967 non-null  object
#  12  start_year  15967 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 1.6+ MB

# %% [markdown]
# # Netero Chatbot

# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.6/320.6 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.5 MB/s eta 0:00:00
# ...

# %%
# %%writefile animeopenai_app.py
import streamlit as st
from openai import OpenAI

# Initialize OpenAI client with your API key
client = OpenAI(api_key="sk-proj-twv0jNl4WAZBOXCCoP1gT3BlbkFJX38wSiu4TXLbtetHisqp")

# Set page title and image
st.markdown(
    "<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>",
    unsafe_allow_html=True
      )


st.title("Let's Talk Anime !")
st.image("/content/drive/MyDrive/animedataset/isaac-netero-png-hunter-x-hunter-netero-png.png")

# Chat history
if "messages" not in st.session_state:
    st.session_state.messages = []

# Display chat messages from history
for message in st.session_state.messages:
    with st.container():
        if message["role"] == "user":
            st.markdown(f"**You:** {message['content']}")
        elif message["role"] == "assistant":
            st.markdown(f"**Netero:** <span style='color:red'>{message['content']}</span>", unsafe_allow_html=True)

# User input
user_input = st.text_input("You:", key="user_input")
if user_input:
    st.session_state.messages.append({"role": "user", "content": user_input})

    openai_prompt = f"Question: {user_input}\nContext: Anime Chatbot\n"
    openai_response = client.completions.create(
        model="gpt-3.5-turbo-instruct",
        prompt=openai_prompt,
        max_tokens=200,
        stream=False
    ).choices[0].text.strip()

    # Display assistant's response immediately
    if openai_response:
        st.session_state.messages.append({"role": "assistant", "content": openai_response})
# Out:
# Overwriting animeopenai_app.py

# %%
# %%writefile animeopenai_app.py
import streamlit as st
from openai import OpenAI

# Initialize OpenAI client with your API key
client = OpenAI(api_key="sk-proj-twv0jNl4WAZBOXCCoP1gT3BlbkFJX38wSiu4TXLbtetHisqp")
st.markdown(
    "<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>",
    unsafe_allow_html=True
      )

# Set page title
st.title("Let's Talk Anime !")

# Create a layout with two columns
col1, col2 = st.columns([3, 2])  # Adjust the ratio as needed

# Chat history
if "messages" not in st.session_state:
    st.session_state.messages = []

# User input
user_input = col1.text_input("You:", key="user_input")
if user_input:
    # Add user input to chat history
    st.session_state.messages.append({"role": "user", "content": user_input})

    # Placeholder for assistant's response
    assistant_response_placeholder = col1.empty()

    # Prompt OpenAI with user input and retrieve response
    openai_prompt = f"Question: {user_input}\nContext: Anime Chatbot\n"
    openai_response = client.completions.create(
        model="gpt-3.5-turbo-instruct",
        prompt=openai_prompt,
        max_tokens=200,
        stream=False
    ).choices[0].text.strip()

    # Display assistant's response
    if openai_response:
        assistant_response_placeholder.markdown(f"**Netero:** <span style='color:red'>{openai_response}</span>", unsafe_allow_html=True)

# Display image in the second column
col2.image("/content/drive/MyDrive/animedataset/isaac-netero-png-hunter-x-hunter-netero-png.png", width=300)
# Out:
# Overwriting animeopenai_app.py

# %%
# %%writefile animeopenai_app.py
import streamlit as st
from openai import OpenAI
def Netero_chatBot() :
    # Initialize OpenAI client with your API key
    client = OpenAI(api_key="sk-proj-twv0jNl4WAZBOXCCoP1gT3BlbkFJX38wSiu4TXLbtetHisqp")
    st.markdown(
    "<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>",
    unsafe_allow_html=True
      )

    # Set page title
    st.title("Let's Talk Anime !")

    # Create a layout with two columns
    col1, col2 = st.columns([4, 2])  # Adjust the ratio as needed

    # Chat history
    if "messages" not in st.session_state:
        st.session_state.messages = []

    # User input
    user_input = col1.text_input("You:", key="user_input")
    if user_input:
        # Add user input to chat history
        st.session_state.messages.append({"role": "user", "content": user_input})

        # Placeholder for assistant's response
        assistant_response_placeholder = col1.empty()

        # Prompt OpenAI with user input and retrieve response
        openai_prompt = f"Question: {user_input}\nContext: Anime Chatbot\n"
        openai_response = client.completions.create(
            model="gpt-3.5-turbo-instruct",
            prompt=openai_prompt,
            max_tokens=500,
            stream=False
        ).choices[0].text.strip()

        # Display assistant's response
        if openai_response:
            assistant_response_placeholder.markdown(f"**Netero:** <span style='color:red'>{openai_response}</span>", unsafe_allow_html=True)

    # Display image in the second column
    col2.image("/content/drive/MyDrive/animedataset/isaac-netero-png-hunter-x-hunter-netero-png.png", width=400)

    return

Netero_chatBot()
# Out:
# Overwriting animeopenai_app.py

# %%
# %%writefile animeopenai_app.py
import streamlit as st
from openai import OpenAI


# Initialize OpenAI client with your API key
client = OpenAI(api_key="sk-proj-twv0jNl4WAZBOXCCoP1gT3BlbkFJX38wSiu4TXLbtetHisqp")
st.markdown("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
st.title("Let's Talk Anime !")

# Create a layout with two columns
col1, col2 = st.columns([4, 2])  # Adjust the ratio as needed

# Chat history
if "messages" not in st.session_state:
    st.session_state.messages = []

# User input
user_input = col1.text_input("You:", key="user_input")
if user_input:
    # Add user input to chat history
    st.session_state.messages.append({"role": "user", "content": user_input})

    # Placeholder for assistant's response
    assistant_response_placeholder = col1.empty()

    # Prompt OpenAI with user input and retrieve response
    openai_prompt = f"Question: {user_input}\nContext: Anime Chatbot\n"
    openai_response = client.completions.create(
        model="gpt-3.5-turbo-instruct",
        prompt=openai_prompt,
        max_tokens=500,
        stream=False
    ).choices[0].text.strip()

    # Display assistant's response
    if openai_response:
        assistant_response_placeholder.markdown(f"**Netero:** <span style='color:red'>{openai_response}</span>", unsafe_allow_html=True)

        # Clear user input after sending the question
        col1.text_input("You:", key="user_input", value="")

# Display image in the second column
col2.image("/content/drive/MyDrive/animedataset/isaac-netero-png-hunter-x-hunter-netero-png.png", width=400)
# Out:
# Overwriting animeopenai_app.py

# %%
# %%writefile animeopenai_app.py
import streamlit as st
from openai import OpenAI
import time

def Netero_chatBot():
    # Initialize OpenAI client with your API key
    client = OpenAI(api_key="sk-proj-twv0jNl4WAZBOXCCoP1gT3BlbkFJX38wSiu4TXLbtetHisqp")
    st.markdown("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
    st.title("Let's Talk Anime !")

    # Create a layout with two columns
    col1, col2 = st.columns([4, 2])  # Adjust the ratio as needed

    # Chat history
    if "messages" not in st.session_state:
        st.session_state.messages = []

    # User input
    user_input = col1.text_input("You:", key=f"user_input_{time.time()}")  # Append timestamp to key
    if user_input:
        # Placeholder for assistant's response
        assistant_response_placeholder = col1.empty()

        # Prompt OpenAI with user input and retrieve response
        openai_prompt = f"Question: {user_input}\nContext: Anime Chatbot\n"
        openai_response = client.completions.create(
            model="gpt-3.5-turbo-instruct",
            prompt=openai_prompt,
            max_tokens=500,
            stream=False
        ).choices[0].text.strip()

        # Add user input to chat history
        st.session_state.messages.append({"role": "user", "content": user_input})

        # Display assistant's response
        if openai_response:
            assistant_response_placeholder.markdown(f"**Netero:** <span style='color:red'>{openai_response}</span>", unsafe_allow_html=True)

            # Clear user input after sending the question
            user_input = ""  # Clear the user input field

    # Display chat history
    if st.session_state.messages:
        col1.markdown("<h3>Chat History:</h3>", unsafe_allow_html=True)
        for message in st.session_state.messages:
            if message["role"] == "user":
                col1.write(f"You: {message['content']}")
            elif message["role"] == "assistant":
                col1.markdown(f"**Netero:** {message['content']}", unsafe_allow_html=True)

    # Display image in the second column
    col2.image("/content/drive/MyDrive/animedataset/isaac-netero-png-hunter-x-hunter-netero-png.png", width=400)

Netero_chatBot()
# Out:
# Overwriting animeopenai_app.py

# %%
#Comple and correct
# %%writefile animeopenai_app.py
import streamlit as st
from openai import OpenAI

# Initialize OpenAI client with your API key
client = OpenAI(api_key="sk-proj-twv0jNl4WAZBOXCCoP1gT3BlbkFJX38wSiu4TXLbtetHisqp")

# Set page title
st.title("Let's Talk Anime !")

# Create a layout with two columns
col1, col2 = st.columns([4, 2])  # Adjust the ratio as needed

# Chat history
if "messages" not in st.session_state:
    st.session_state.messages = []

# User input
user_input = col1.text_input("You:", key="user_input")
if user_input:
    st.session_state.messages.append({"role": "user", "content": user_input})

    openai_prompt = f"Question: {user_input}\nContext: Anime Chatbot\n"
    openai_response = client.completions.create(
        model="gpt-3.5-turbo-instruct",
        prompt=openai_prompt,
        max_tokens=200,
        stream=False
    ).choices[0].text.strip()

    # Display assistant's response immediately
    if openai_response:
        st.session_state.messages.append({"role": "assistant", "content": openai_response})

# Display chat messages from history
for message in st.session_state.messages:
    if message["role"] == "user":
        col1.markdown(f"**You:** {message['content']}")
    elif message["role"] == "assistant":
        col1.markdown(f"**Netero:** <span style='color:red'>{message['content']}</span>", unsafe_allow_html=True)

# Display image in the second column
col2.image("/content/drive/MyDrive/animedataset/isaac-netero-png-hunter-x-hunter-netero-png.png", width=400)
# Out:
# Overwriting animeopenai_app.py

# %%
#Comple and correct
# %%writefile animeopenai_app.py
import streamlit as st
from openai import OpenAI

# Initialize OpenAI client with your API key
client = OpenAI(api_key="sk-proj-twv0jNl4WAZBOXCCoP1gT3BlbkFJX38wSiu4TXLbtetHisqp")

# Set page title
st.title("Let's Talk Anime !")

# Create a layout with two columns
col1, col2 = st.columns([4, 2])  # Adjust the ratio as needed

# Chat history
if "messages" not in st.session_state:
    st.session_state.messages = []

# User input
user_input = col1.text_input("You:", key="user_input")
if user_input:
    st.session_state.messages.append({"role": "user", "content": user_input})

    openai_prompt = f"Question: {user_input}\nContext: Anime Chatbot\n"
    openai_response = client.completions.create(
        model="gpt-3.5-turbo-instruct",
        prompt=openai_prompt,
        max_tokens=200,
        stream=False
    ).choices[0].text.strip()

    # Display assistant's response immediately
    if openai_response:
        st.session_state.messages.append({"role": "assistant", "content": openai_response})

# Display chat messages from history
for message in st.session_state.messages:
    if message["role"] == "user":
        col1.markdown(f"**You:** {message['content']}")
    elif message["role"] == "assistant":
        col1.markdown(f"**Netero:** <span style='color:red'>{message['content']}</span>", unsafe_allow_html=True)

# Display image in the second column
col2.image("/content/drive/MyDrive/netro2.png", width=400)
# Out:
# Overwriting animeopenai_app.py

# %%
# !streamlit run animeopenai_app.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 35.221.3.244
# npx: installed 22 in 4.52s
# your url is: https://eight-comics-act.loca.lt

# %% [markdown]
# # all

# %%
# Combine all code into one Streamlit app
# %%writefile Animeapp.py
import streamlit as st
import pandas as pd
import functions

# Load CSV into DataFrame
csv_file_path = '/content/drive/MyDrive/user_data.csv'  # Define the CSV file path
user_df = pd.read_csv(csv_file_path)
user_df['password'] = user_df['password'].astype(str)

# Load anime DataFrame
file_path = '/content/drive/MyDrive/animedataset/anime_clean.csv'
anime_df = pd.read_csv(file_path)

# Load user list
user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')

# Load final anime dataset
file_path_final = '/content/drive/MyDrive/final_animedataset.csv'
anime23 = pd.read_csv(file_path_final, nrows=200000)

# Get the current year
current_year = pd.Timestamp.now().year
years = list(range(1959, current_year + 1))
top_anime = None

import streamlit as st

def login(user_df):
    mail = st.text_input('Email', key='login-email')
    password = st.text_input('Password', type='password', key='login-password')

    if st.button('Login'):
        # Check if the email and password match
        match_condition = ((user_df['mail'] == mail) & (user_df['password'] == password))

        if match_condition.any():
            user_name = user_df.loc[match_condition, 'user_name'].iloc[0]  # Get the user name
            st.session_state.user_name = user_name  # Store the user name in session state
            st.success("Login successful!")
            return user_name  # Return the user name
        else:
            st.error("Invalid email or password. Please try again.")
            return None  # Return None if login fails
    else:
        return None  # Return None if login button is not clicked


def add_to_user_list(user_name, title, img_url, rating):
    global user_list
    if user_list.empty:
        user_list = pd.DataFrame({'user_name': [user_name], 'title': [title], 'img_url': [img_url], 'rating': [rating]})
    else:
        new_row = pd.DataFrame({'user_name': [user_name], 'title': [title], 'img_url': [img_url], 'rating': [rating]})
        user_list = pd.concat([user_list, new_row], ignore_index=True)
    user_list.to_csv('/content/drive/MyDrive/user_list.csv', index=False)

def display_user_list(user_name):
    global user_list
    user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')
    st.write(f"Viewing My List for {user_name}...")
    user_list_filtered = user_list[user_list['user_name'] == user_name]
    if not user_list_filtered.empty:
        for index, row in user_list_filtered.iterrows():
            st.image(row['img_url'], caption=row['title'], width=150)
            st.write(f"**Title:** {row['title']}")
            st.write(f"**Rating:** {row['rating']}")
    else:
        st.write("Your list is empty.")

def display_info(selected_anime, anime_df, user_df, user_name):
    anime_info = anime_df[anime_df['title'] == selected_anime]
    title = anime_info['title'].iloc[0]
    genre = anime_info['genre'].iloc[0]
    episodes = anime_info['episodes'].iloc[0]
    score = anime_info['score'].iloc[0]
    synopsis = anime_info['synopsis'].iloc[0]
    img_url = anime_info['img_url'].iloc[0]

    st.write(f"**Title:** {title}")
    st.write(f"**Genre:** {genre}")
    st.write(f"**Episodes:** {episodes}")
    st.write(f"**Score:** {score}")
    st.write(f"**Synopsis:** {synopsis}")

    st.image(img_url, caption=title, width=300)

    rating = st.selectbox("Rate this anime (1-10)", list(range(1, 11)))
    add_to_list = st.button("Add to My List")
    view_my_list = st.button("View My List")

    if rating:
        st.write(f"You rated '{title}' as: {rating}/10")

    if add_to_list:
        st.write(f"'{title}' added to My List")
        add_to_user_list(user_name, selected_anime, img_url, rating)

    if view_my_list:
        display_user_list(user_name)

def main():
    st.write("<h1 style='color:blue;'>Anime Alchemist</h1>", unsafe_allow_html=True)
    st.markdown("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
    st.title('Login Here !')
    menu = st.sidebar.selectbox('Menu', ['Login', 'Create Account'])
    if menu == 'Login':
        login(user_df)
    elif menu == 'Create Account':
        return_to_login = functions.create_account(csv_file_path)
        if return_to_login:
            login(user_df)

    if st.session_state.logged_in:
        user_name = st.session_state.user_name
        st.write(f"<p style='font-size: 24px; color: #FF9999;'>Welcome back {user_name}!</p>", unsafe_allow_html=True)
        st.write("<h1 style='color:blue;'>Anime Alchemist</h1>", unsafe_allow_html=True)
        st.image("/content/drive/MyDrive/anime.jpg", use_column_width=True)

        st.sidebar.markdown("<h2 style='text-align: center;'>Features</h2>", unsafe_allow_html=True)
        get_recommendation = st.sidebar.button("Get Recommendation")
        playlist = st.sidebar.button(f"{user_name}'s Playlist")
        chat_with_netero = st.sidebar.button("Chat with Netero")

        if get_recommendation:
            st.experimental_rerun()

        if playlist:
            st.experimental_rerun()

        if chat_with_netero:
            st.experimental_rerun()

if __name__ == '__main__':
    main()

# Code for recommendation page
if st.session_state.get_recommendation:
    st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
    st.markdown(
        "<h1 style='text-align: center; color: #FF5733;'> Get Anime Recommendations</h1>",
        unsafe_allow_html=True
    )

    selectbox_key = "choose_recommendation"
    option = st.sidebar.selectbox("Choose a recommendation",
                                   ["Top Rated", "Most Popular", "By Genre",
                                    "By Year", "By Anime", "By Story",
                                    "Surprise Me"],
                                   key=selectbox_key)

    if option == "Top Rated":
        top_anime = functions.get_top_anime_rating(anime_df, 10)
        top_anime.reset_index(drop=True, inplace=True)

    elif option == "Most Popular":
        top_anime = functions.get_top_anime_popularity(anime_df, 10)
        top_anime.reset_index(drop=True, inplace=True)

    elif option == "By Genre":
        genres = functions.get_top_unique_genre(anime_df)
        chosen_genre = st.sidebar.selectbox("Select a genre", genres)
        top_anime = functions.get_top_titles_for_genre(anime_df, chosen_genre)
        top_anime.reset_index(drop=True, inplace=True)

    if option == "By Year":
        chosen_year = st.sidebar.selectbox("Select a year", years)
        top_anime = functions.get_top_anime_by_year(anime_df, chosen_year)
        top_anime.reset_index(drop=True, inplace=True)

    elif option == "By Anime":
        anime_titles = anime_df['title'].tolist()
        chosen_anime = st.sidebar.selectbox("Select an anime", anime_titles)
        top_anime = functions.find_similar_byanime(chosen_anime, anime23, 10)

    elif option == "By Story":
        anime_titles = anime_df['title'].tolist()
        chosen_anime = st.sidebar.selectbox("Select an anime", anime_titles)
        top_anime = functions.get_top_similar_anime_by_synopsis(anime_df, chosen_anime, 15)
        top_anime.reset_index(drop=True, inplace=True)

    elif option == "Surprise Me":
        user_name = st.sidebar.text_input("Enter your username")
        num = st.sidebar.slider("Number of recommendations", 1, 10)

        if user_name:
            recommendations = functions.get_surprise_recommendations(anime23, user_name, num)
            if isinstance(recommendations, str):
                st.write(recommendations)
            else:
                st.write("**Top Recommendations:**")
                for idx, (title, rating) in enumerate(recommendations, start=1):
                    st.write(f"{idx}. {title}: {rating}/10")
        else:
            st.write("Please enter a username to get Surprise Me recommendations.")

    if top_anime is not None:
        for index, anime in top_anime.iterrows():
            if anime['img_url']:
                st.image(anime['img_url'], caption=anime['title'], width=150)
            else:
                st.write(anime['title'])

# Code for playlist page
if st.session_state.playlist:
    st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
    st.markdown(
        "<h1 style='text-align: center; color: #FF5733;'> My Playlist</h1>",
        unsafe_allow_html=True
    )
    user_name = st.session_state.user_name
    display_user_list(user_name)

# Code for chat with Netero page
if st.session_state.chat_with_netero:
    st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
    st.markdown(
        "<h1 style='text-align: center; color: #FF5733;'> Chat with Netero</h1>",
        unsafe_allow_html=True
    )
    functions.Netero_chatBot()
    return_to_main = st.button("Return to Main")
    if return_to_main:
        st.experimental_rerun()
# Out:
# Writing Animeapp.py

# %%
# %%writefile Animeapp.py
import streamlit as st
import pandas as pd
import functions

# Load CSV into DataFrame
csv_file_path = '/content/drive/MyDrive/user_data.csv'  # Define the CSV file path
user_df = pd.read_csv(csv_file_path)
user_df['password'] = user_df['password'].astype(str)

# Load anime DataFrame
file_path = '/content/drive/MyDrive/animedataset/anime_clean.csv'
anime_df = pd.read_csv(file_path)

# Load user list
user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')

# Load final anime dataset
file_path_final = '/content/drive/MyDrive/final_animedataset.csv'
anime23 = pd.read_csv(file_path_final, nrows=200000)

# Get the current year
current_year = pd.Timestamp.now().year
years = list(range(1959, current_year + 1))

def add_to_user_list(user_name, title, img_url, rating):
    global user_list
    if user_list.empty:
        user_list = pd.DataFrame({'user_name': [user_name], 'title': [title], 'img_url': [img_url], 'rating': [rating]})
    else:
        new_row = pd.DataFrame({'user_name': [user_name], 'title': [title], 'img_url': [img_url], 'rating': [rating]})
        user_list = pd.concat([user_list, new_row], ignore_index=True)
    user_list.to_csv('/content/drive/MyDrive/user_list.csv', index=False)

def display_user_list(user_name):
    global user_list
    user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')
    st.write(f"Viewing My List for {user_name}...")
    user_list_filtered = user_list[user_list['user_name'] == user_name]
    if not user_list_filtered.empty:
        for index, row in user_list_filtered.iterrows():
            st.image(row['img_url'], caption=row['title'], width=150)
            st.write(f"**Title:** {row['title']}")
            st.write(f"**Rating:** {row['rating']}")
    else:
        st.write("Your list is empty.")

def display_info(selected_anime, anime_df, user_df, user_name):
    anime_info = anime_df[anime_df['title'] == selected_anime]
    title = anime_info['title'].iloc[0]
    genre = anime_info['genre'].iloc[0]
    episodes = anime_info['episodes'].iloc[0]
    score = anime_info['score'].iloc[0]
    synopsis = anime_info['synopsis'].iloc[0]
    img_url = anime_info['img_url'].iloc[0]

    st.write(f"**Title:** {title}")
    st.write(f"**Genre:** {genre}")
    st.write(f"**Episodes:** {episodes}")
    st.write(f"**Score:** {score}")
    st.write(f"**Synopsis:** {synopsis}")

    st.image(img_url, caption=title, width=300)

    rating = st.selectbox("Rate this anime (1-10)", list(range(1, 11)))
    add_to_list = st.button("Add to My List")
    view_my_list = st.button("View My List")

    if rating:
        st.write(f"You rated '{title}' as: {rating}/10")

    if add_to_list:
        st.write(f"'{title}' added to My List")
        add_to_user_list(user_name, selected_anime, img_url, rating)

    if view_my_list:
        display_user_list(user_name)

def main():
    csv_file_path = '/content/drive/MyDrive/user_data.csv'  # Define the CSV file path

    st.write("<h1 style='color:blue;'>Anime Alchemist</h1>", unsafe_allow_html=True)

    # Display image at the top with full width and shorter height
    #st.image('/content/drive/MyDrive/anime.jpg', use_column_width=True)
    st.markdown(
    "<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>",
    unsafe_allow_html=True
      )

    st.title('Login Here !')

    menu = st.sidebar.selectbox('Menu', ['Login', 'Create Account'])

    if menu == 'Login':
        if functions.login(user_df):
            st.session_state.logged_in = True
    elif menu == 'Create Account':
        return_to_login = functions.create_account(csv_file_path)  # Pass csv_file_path here

        # Redirect to login page if return button is clicked
        if return_to_login:
            functions.login(user_df)

    # Redirect to the second page if logged in successfully
    if st.session_state.logged_in:
        st.markdown("<h2 style='text-align: center;'>Redirecting...</h2>", unsafe_allow_html=True)
        st.experimental_rerun()


    st.write("<h1 style='color:blue;'>The Anime Alchemist</h1>", unsafe_allow_html=True)
    st.markdown("<h1 style='text-align: center; color: #FF5733;'> For All Anime Lovers !</h1>", unsafe_allow_html=True)
    #st.title('Login Here !')
    menu = st.sidebar.selectbox('Menu', ['Login', 'Create Account'])
    if menu == 'Login':
        st.title('Login Here !')
        functions.login(user_df)
    elif menu == 'Create Account':
        st.title('Create account !')
        return_to_login = functions.create_account(csv_file_path)
        if return_to_login:
            functions.login(user_df)

    if st.session_state.logged_in:
        user_name = st.session_state.user_name
        st.write(f"<p style='font-size: 24px; color: #FF9999;'>Welcome back {user_name}!</p>", unsafe_allow_html=True)
        st.write("<h1 style='color:blue;'>Anime Alchemist</h1>", unsafe_allow_html=True)
        st.image("/content/drive/MyDrive/anime.jpg", use_column_width=True)

        st.sidebar.markdown("<h2 style='text-align: center;'>Features</h2>", unsafe_allow_html=True)
        get_recommendation = st.sidebar.button("Get Recommendation")
        playlist = st.sidebar.button(f"{user_name}'s Playlist")
        chat_with_netero = st.sidebar.button("Chat with Netero")

        if get_recommendation:
            st.experimental_rerun()

        if playlist:
            st.experimental_rerun()

        if chat_with_netero:
            st.experimental_rerun()

    if st.session_state.get_recommendation:
        st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
        st.markdown("<h1 style='text-align: center; color: #FF5733;'> Get Anime Recommendations</h1>", unsafe_allow_html=True)

        selectbox_key = "choose_recommendation"
        option = st.sidebar.selectbox("Choose a recommendation",
                                       ["Top Rated", "Most Popular", "By Genre",
                                        "By Year", "By Anime", "By Story",
                                        "Surprise Me"],
                                       key=selectbox_key)

        if option == "Top Rated":
            top_anime = functions.get_top_anime_rating(anime_df, 10)
            top_anime.reset_index(drop=True, inplace=True)

        elif option == "Most Popular":
            top_anime = functions.get_top_anime_popularity(anime_df, 10)
            top_anime.reset_index(drop=True, inplace=True)

        elif option == "By Genre":
            genres = functions.get_top_unique_genre(anime_df)
            chosen_genre = st.sidebar.selectbox("Select a genre", genres)
            top_anime = functions.get_top_titles_for_genre(anime_df, chosen_genre)
            top_anime.reset_index(drop=True, inplace=True)

        if option == "By Year":
            chosen_year = st.sidebar.selectbox("Select a year", years)
            top_anime = functions.get_top_anime_by_year(anime_df, chosen_year)
            top_anime.reset_index(drop=True, inplace=True)

        elif option == "By Anime":
            anime_titles = anime_df['title'].tolist()
            chosen_anime = st.sidebar.selectbox("Select an anime", anime_titles)
            top_anime = functions.find_similar_byanime(chosen_anime, anime23, 10)

        elif option == "By Story":
            anime_titles = anime_df['title'].tolist()
            chosen_anime = st.sidebar.selectbox("Select an anime", anime_titles)
            top_anime = functions.get_top_similar_anime_by_synopsis(anime_df, chosen_anime, 15)
            top_anime.reset_index(drop=True, inplace=True)

        elif option == "Surprise Me":
            user_name = st.sidebar.text_input("Enter your username")
            num = st.sidebar.slider("Number of recommendations", 1, 10)

            if user_name:
                recommendations = functions.get_surprise_recommendations(anime23, user_name, num)
                if isinstance(recommendations, str):
                    st.write(recommendations)
                else:
                    st.write("**Top Recommendations:**")
                    for idx, (title, rating) in enumerate(recommendations, start=1):
                        st.write(f"{idx}. {title}: {rating}/10")
            else:
                st.write("Please enter a username to get Surprise Me recommendations.")

        if top_anime is not None:
            for index, anime in top_anime.iterrows():
                if anime['img_url']:
                    st.image(anime['img_url'], caption=anime['title'], width=150)
                else:
                    st.write(anime['title'])

    if st.session_state.playlist:
        st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
        st.markdown("<h1 style='text-align: center; color: #FF5733;'> My Playlist</h1>", unsafe_allow_html=True)
        user_name = st.session_state.user_name
        display_user_list(user_name)

    if st.session_state.chat_with_netero:
        st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
        st.markdown("<h1 style='text-align: center; color: #FF5733;'> Chat with Netero</h1>", unsafe_allow_html=True)
        functions.Netero_chatBot()
        return_to_main = st.button("Return to Main")
        if return_to_main:
            st.experimental_rerun()

if __name__ == '__main__':
    main()
# Out:
# Overwriting Animeapp.py

# %%
# %%writefile Animeapp.py
import streamlit as st
import pandas as pd
import functions

# Load CSV into DataFrame
csv_file_path = '/content/drive/MyDrive/user_data.csv'  # Define the CSV file path
user_df = pd.read_csv(csv_file_path)
user_df['password'] = user_df['password'].astype(str)

# Load anime DataFrame
file_path = '/content/drive/MyDrive/animedataset/anime_clean.csv'
anime_df = pd.read_csv(file_path)

# Load user list
user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')

# Load final anime dataset
file_path_final = '/content/drive/MyDrive/final_animedataset.csv'
anime23 = pd.read_csv(file_path_final, nrows=200000)

# Get the current year
current_year = pd.Timestamp.now().year
years = list(range(1959, current_year + 1))

def add_to_user_list(user_name, title, img_url, rating):
    global user_list
    if user_list.empty:
        user_list = pd.DataFrame({'user_name': [user_name], 'title': [title], 'img_url': [img_url], 'rating': [rating]})
    else:
        new_row = pd.DataFrame({'user_name': [user_name], 'title': [title], 'img_url': [img_url], 'rating': [rating]})
        user_list = pd.concat([user_list, new_row], ignore_index=True)
    user_list.to_csv('/content/drive/MyDrive/user_list.csv', index=False)

def display_user_list(user_name):
    global user_list
    user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')
    st.write(f"Viewing My List for {user_name}...")
    user_list_filtered = user_list[user_list['user_name'] == user_name]
    if not user_list_filtered.empty:
        for index, row in user_list_filtered.iterrows():
            st.image(row['img_url'], caption=row['title'], width=150)
            st.write(f"**Title:** {row['title']}")
            st.write(f"**Rating:** {row['rating']}")
    else:
        st.write("Your list is empty.")

def display_info(selected_anime, anime_df, user_df, user_name):
    anime_info = anime_df[anime_df['title'] == selected_anime]
    title = anime_info['title'].iloc[0]
    genre = anime_info['genre'].iloc[0]
    episodes = anime_info['episodes'].iloc[0]
    score = anime_info['score'].iloc[0]
    synopsis = anime_info['synopsis'].iloc[0]
    img_url = anime_info['img_url'].iloc[0]

    st.write(f"**Title:** {title}")
    st.write(f"**Genre:** {genre}")
    st.write(f"**Episodes:** {episodes}")
    st.write(f"**Score:** {score}")
    st.write(f"**Synopsis:** {synopsis}")

    st.image(img_url, caption=title, width=300)

    rating = st.selectbox("Rate this anime (1-10)", list(range(1, 11)))
    add_to_list = st.button("Add to My List")
    view_my_list = st.button("View My List")

    if rating:
        st.write(f"You rated '{title}' as: {rating}/10")

    if add_to_list:
        st.write(f"'{title}' added to My List")
        add_to_user_list(user_name, selected_anime, img_url, rating)

    if view_my_list:
        display_user_list(user_name)

def main():
    st.session_state.logged_in = False
    st.session_state.get_recommendation = False
    st.session_state.playlist = False
    st.session_state.chat_with_netero = False

    st.write("<h1 style='color:blue;'>Anime Alchemist</h1>", unsafe_allow_html=True)
    st.markdown("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)

    st.title('Login Here !')

    menu = st.sidebar.selectbox('Menu', ['Login', 'Create Account'])

    if menu == 'Login':
        if functions.login(user_df):
            st.session_state.logged_in = True
            st.experimental_rerun()
    elif menu == 'Create Account':
        return_to_login = functions.create_account(csv_file_path)  # Pass csv_file_path here

        # Redirect to login page if return button is clicked
        if return_to_login:
            functions.login(user_df)
            st.experimental_rerun()

    # Redirect to the second page if logged in successfully
    if st.session_state.logged_in:
        st.write("<h2 style='text-align: center;'>Redirecting...</h2>", unsafe_allow_html=True)
        st.experimental_rerun()

    # Second Page
    st.write("<h1 style='color:blue;'>The Anime Alchemist</h1>", unsafe_allow_html=True)
    st.markdown("<h1 style='text-align: center; color: #FF5733;'> For All Anime Lovers !</h1>", unsafe_allow_html=True)
    menu = st.sidebar.selectbox('Menu', ['Get Recommendation', "My Playlist", "Chat with Netero"])

    if menu == 'Get Recommendation':
        st.session_state.get_recommendation = True
        st.experimental_rerun()
    elif menu == 'My Playlist':
        st.session_state.playlist = True
        st.experimental_rerun()
    elif menu == 'Chat with Netero':
        st.session_state.chat_with_netero = True
        st.experimental_rerun()

    if st.session_state.get_recommendation:
        st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
        st.markdown("<h1 style='text-align: center; color: #FF5733;'> Get Anime Recommendations</h1>", unsafe_allow_html=True)
        # Add recommendation logic here

    if st.session_state.playlist:
        st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
        st.markdown("<h1 style='text-align: center; color: #FF5733;'> My Playlist</h1>", unsafe_allow_html=True)
        # Add playlist logic here

    if st.session_state.chat_with_netero:
        st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
        st.markdown("<h1 style='text-align: center; color: #FF5733;'> Chat with Netero</h1>", unsafe_allow_html=True)
        functions.Netero_chatBot()
        return_to_main = st.button("Return to Main")
        if return_to_main:
            st.experimental_rerun()

if __name__ == '__main__':
    main()
# Out:
# Overwriting Animeapp.py

# %%
# %%writefile Animeapp.py
import streamlit as st
import pandas as pd
import functions

# Load CSV into DataFrame
csv_file_path = '/content/drive/MyDrive/user_data.csv'  # Define the CSV file path
user_df = pd.read_csv(csv_file_path)
user_df['password'] = user_df['password'].astype(str)

# Load anime DataFrame
file_path = '/content/drive/MyDrive/animedataset/anime_clean.csv'
anime_df = pd.read_csv(file_path)

# Load user list
user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')

# Load final anime dataset
file_path_final = '/content/drive/MyDrive/final_animedataset.csv'
anime23 = pd.read_csv(file_path_final, nrows=200000)

# Get the current year
current_year = pd.Timestamp.now().year
years = list(range(1959, current_year + 1))

def add_to_user_list(user_name, title, img_url, rating):
    global user_list
    if user_list.empty:
        user_list = pd.DataFrame({'user_name': [user_name], 'title': [title], 'img_url': [img_url], 'rating': [rating]})
    else:
        new_row = pd.DataFrame({'user_name': [user_name], 'title': [title], 'img_url': [img_url], 'rating': [rating]})
        user_list = pd.concat([user_list, new_row], ignore_index=True)
    user_list.to_csv('/content/drive/MyDrive/user_list.csv', index=False)

def display_user_list(user_name):
    global user_list
    user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')
    st.write(f"Viewing My List for {user_name}...")
    user_list_filtered = user_list[user_list['user_name'] == user_name]
    if not user_list_filtered.empty:
        for index, row in user_list_filtered.iterrows():
            st.image(row['img_url'], caption=row['title'], width=150)
            st.write(f"**Title:** {row['title']}")
            st.write(f"**Rating:** {row['rating']}")
    else:
        st.write("Your list is empty.")

def display_info(selected_anime, anime_df, user_df, user_name):
    anime_info = anime_df[anime_df['title'] == selected_anime]
    title = anime_info['title'].iloc[0]
    genre = anime_info['genre'].iloc[0]
    episodes = anime_info['episodes'].iloc[0]
    score = anime_info['score'].iloc[0]
    synopsis = anime_info['synopsis'].iloc[0]
    img_url = anime_info['img_url'].iloc[0]

    st.write(f"**Title:** {title}")
    st.write(f"**Genre:** {genre}")
    st.write(f"**Episodes:** {episodes}")
    st.write(f"**Score:** {score}")
    st.write(f"**Synopsis:** {synopsis}")

    st.image(img_url, caption=title, width=300)

    rating = st.selectbox("Rate this anime (1-10)", list(range(1, 11)))
    add_to_list = st.button("Add to My List")
    view_my_list = st.button("View My List")

    if rating:
        st.write(f"You rated '{title}' as: {rating}/10")

    if add_to_list:
        st.write(f"'{title}' added to My List")
        add_to_user_list(user_name, selected_anime, img_url, rating)

    if view_my_list:
        display_user_list(user_name)

def main():
    st.session_state.logged_in = False
    st.session_state.get_recommendation = False
    st.session_state.playlist = False
    st.session_state.chat_with_netero = False

    st.write("<h1 style='color:blue;'>Anime Alchemist</h1>", unsafe_allow_html=True)
    st.markdown("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)

    st.title('Login Here !')

    menu = st.sidebar.selectbox('Menu', ['Login', 'Create Account'])

    if menu == 'Login':
        if functions.login(user_df):
            st.session_state.logged_in = True
            st.experimental_rerun()
    elif menu == 'Create Account':
        return_to_login = functions.create_account(csv_file_path)  # Pass csv_file_path here

        # Redirect to login page if return button is clicked
        if return_to_login:
            functions.login(user_df)
            st.experimental_rerun()

    # Redirect to the second page if logged in successfully
    if st.session_state.logged_in:
        st.write("<h2 style='text-align: center;'>Redirecting...</h2>", unsafe_allow_html=True)
        st.experimental_rerun()

    # Second Page
    st.write("<h1 style='color:blue;'>The Anime Alchemist</h1>", unsafe_allow_html=True)
    st.markdown("<h1 style='text-align: center; color: #FF5733;'> For All Anime Lovers !</h1>", unsafe_allow_html=True)
    menu = st.sidebar.selectbox('Menu', ['Get Recommendation', "My Playlist", "Chat with Netero"])

    if menu == 'Get Recommendation':
        st.session_state.get_recommendation = True
        st.experimental_rerun()
    elif menu == 'My Playlist':
        st.session_state.playlist = True
        st.experimental_rerun()
    elif menu == 'Chat with Netero':
        st.session_state.chat_with_netero = True
        st.experimental_rerun()

    if st.session_state.get_recommendation:
        st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
        st.markdown("<h1 style='text-align: center; color: #FF5733;'> Get Anime Recommendations</h1>", unsafe_allow_html=True)
        # Add recommendation logic here

    if st.session_state.playlist:
        st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
        st.markdown("<h1 style='text-align: center; color: #FF5733;'> My Playlist</h1>", unsafe_allow_html=True)
        # Add playlist logic here

    if st.session_state.chat_with_netero:
        st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
        st.markdown("<h1 style='text-align: center; color: #FF5733;'> Chat with Netero</h1>", unsafe_allow_html=True)
        functions.Netero_chatBot()
        return_to_main = st.button("Return to Main")
        if return_to_main:
            st.experimental_rerun()

if __name__ == '__main__':
    main()
# Out:
# Overwriting Animeapp.py

# %%
# %%writefile Animeapp.py
import streamlit as st
import pandas as pd
import functions

# Load CSV into DataFrame
csv_file_path = '/content/drive/MyDrive/user_data.csv'  # Define the CSV file path
user_df = pd.read_csv(csv_file_path)
user_df['password'] = user_df['password'].astype(str)

# Load anime DataFrame
file_path = '/content/drive/MyDrive/animedataset/anime_clean.csv'
anime_df = pd.read_csv(file_path)

# Load user list
user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')

# Load final anime dataset
file_path_final = '/content/drive/MyDrive/final_animedataset.csv'
anime23 = pd.read_csv(file_path_final, nrows=200000)

# Get the current year
current_year = pd.Timestamp.now().year
years = list(range(1959, current_year + 1))

def add_to_user_list(user_name, title, img_url, rating):
    global user_list
    if user_list.empty:
        user_list = pd.DataFrame({'user_name': [user_name], 'title': [title], 'img_url': [img_url], 'rating': [rating]})
    else:
        new_row = pd.DataFrame({'user_name': [user_name], 'title': [title], 'img_url': [img_url], 'rating': [rating]})
        user_list = pd.concat([user_list, new_row], ignore_index=True)
    user_list.to_csv('/content/drive/MyDrive/user_list.csv', index=False)

def display_user_list(user_name):
    global user_list
    user_list = pd.read_csv('/content/drive/MyDrive/user_list.csv')
    st.write(f"Viewing My List for {user_name}...")
    user_list_filtered = user_list[user_list['user_name'] == user_name]
    if not user_list_filtered.empty:
        for index, row in user_list_filtered.iterrows():
            st.image(row['img_url'], caption=row['title'], width=150)
            st.write(f"**Title:** {row['title']}")
            st.write(f"**Rating:** {row['rating']}")
    else:
        st.write("Your list is empty.")

def display_info(selected_anime, anime_df, user_df, user_name):
    anime_info = anime_df[anime_df['title'] == selected_anime]
    title = anime_info['title'].iloc[0]
    genre = anime_info['genre'].iloc[0]
    episodes = anime_info['episodes'].iloc[0]
    score = anime_info['score'].iloc[0]
    synopsis = anime_info['synopsis'].iloc[0]
    img_url = anime_info['img_url'].iloc[0]

    st.write(f"**Title:** {title}")
    st.write(f"**Genre:** {genre}")
    st.write(f"**Episodes:** {episodes}")
    st.write(f"**Score:** {score}")
    st.write(f"**Synopsis:** {synopsis}")

    st.image(img_url, caption=title, width=300)

    rating = st.selectbox("Rate this anime (1-10)", list(range(1, 11)))
    add_to_list = st.button("Add to My List")
    view_my_list = st.button("View My List")

    if rating:
        st.write(f"You rated '{title}' as: {rating}/10")

    if add_to_list:
        st.write(f"'{title}' added to My List")
        add_to_user_list(user_name, selected_anime, img_url, rating)

    if view_my_list:
        display_user_list(user_name)

def main():
    st.session_state.logged_in = False
    st.session_state.get_recommendation = False
    st.session_state.playlist = False
    st.session_state.chat_with_netero = False

    st.write("<h1 style='color:blue;'>Anime Alchemist</h1>", unsafe_allow_html=True)
    st.markdown("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)

    st.title('Login Here !')

    menu = st.sidebar.selectbox('Menu', ['Login', 'Create Account'])

    if menu == 'Login':
        if functions.login(user_df):
            st.session_state.logged_in = True
            st.experimental_rerun()
    elif menu == 'Create Account':
        return_to_login = functions.create_account(csv_file_path)  # Pass csv_file_path here

        # Redirect to login page if return button is clicked
        if return_to_login:
            functions.login(user_df)
            st.experimental_rerun()

    # Redirect to the second page if logged in successfully
    if st.session_state.logged_in:
        st.write("<h2 style='text-align: center;'>Redirecting...</h2>", unsafe_allow_html=True)
        st.experimental_rerun()

    # Second Page
    st.write("<h1 style='color:blue;'>The Anime Alchemist</h1>", unsafe_allow_html=True)
    st.markdown("<h1 style='text-align: center; color: #FF5733;'> For All Anime Lovers !</h1>", unsafe_allow_html=True)
    menu = st.sidebar.selectbox('Menu', ['Get Recommendation', "My Playlist", "Chat with Netero"])

    if menu == 'Get Recommendation':
        st.session_state.get_recommendation = True
        st.experimental_rerun()
    elif menu == 'My Playlist':
        st.session_state.playlist = True
        st.experimental_rerun()
    elif menu == 'Chat with Netero':
        st.session_state.chat_with_netero = True
        st.experimental_rerun()

    if st.session_state.get_recommendation:
        st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
        st.markdown("<h1 style='text-align: center; color: #FF5733;'> Get Anime Recommendations</h1>", unsafe_allow_html=True)
        # Add recommendation logic here

    if st.session_state.playlist:
        st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
        st.markdown("<h1 style='text-align: center; color: #FF5733;'> My Playlist</h1>", unsafe_allow_html=True)
        # Add playlist logic here

    if st.session_state.chat_with_netero:
        st.write("<h1 style='text-align: center; color: #FF5733;'> The Anime Alchemist</h1>", unsafe_allow_html=True)
        st.markdown("<h1 style='text-align: center; color: #FF5733;'> Chat with Netero</h1>", unsafe_allow_html=True)
        functions.Netero_chatBot()
        return_to_main = st.button("Return to Main")
        if return_to_main:
            st.experimental_rerun()

if __name__ == '__main__':
    main()
# Out:
# Overwriting Animeapp.py

# %%
# !streamlit run Animeapp.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.16.55.173
# npx: installed 22 in 3.993s
# your url is: https://strong-toes-fry.loca.lt
